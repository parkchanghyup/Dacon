# %%
import warnings
warnings.filterwarnings(action='ignore')

import os
import pandas as pd
import numpy as np

from PIL import Image
import matplotlib.pyplot as plt
# %matplotlib inline

from sklearn.model_selection import train_test_split
import IPython.display as ipd
import time

# %%
from torch.utils.data import Dataset
from torch.utils.data import DataLoader

import torch
import torchvision
import torch.nn.functional as F
from torchvision.transforms import functional
from torch import Tensor, nn, optim
from torch.utils.data import Dataset, DataLoader
from torchvision.utils import make_grid
import torchvision.transforms as transforms
import albumentations as A
from albumentations.pytorch import ToTensor

from efficientnet_pytorch import EfficientNet

# %%
import torch
import torchvision
import torch.nn.functional as F
import torch.optim as optim
from torch.utils.data import Dataset, DataLoader
import torch.nn as nn
import torchvision.transforms as transforms
import torchvision.models as models
from adamp import AdamP
from torchsummary import summary

# %% [markdown]
# ## 시드 고정

# %%
import random
def seed_everything(seed: int = 42):
    random.seed(seed)
    np.random.seed(seed)
    os.environ["PYTHONHASHSEED"] = str(seed)
    torch.manual_seed(seed)
    torch.cuda.manual_seed(seed)  
    torch.backends.cudnn.deterministic = True  
    torch.backends.cudnn.benchmark = True  
seed_everything()

# %% [markdown]
# ## 데이터 불러오기

# %%
train = pd.read_csv('./train/train_data.csv')
test = pd.read_csv('./test/test/test_data.csv')

# %%
train.columns = ['file_name','label']

# %%
test.head()
# Out:
#      file_name
# 0  idx0001.png
# 1  idx0002.png
# 2  idx0003.png
# 3  idx0004.png
# 4  idx0005.png

# %%
class CustomDataset(torch.utils.data.Dataset): 
    def __init__(self,df,path,option,augmentation=None):
        self.df = df
        self.option = option
        self.augmentation = augmentation
        self.path = path

    def __len__(self):
        return len(self.df)
    
    def __getitem__(self, idx): 
        file_path  = self.df.iloc[idx,0]
        image=  Image.open(os.path.join(self.path,file_path)).convert('RGB')
        image = image.resize((100,100))
        image = np.array(image)
        
        #image = transforms.ToTensor()(image=image)['image']
        
        
        if self.augmentation is not None:
            image = self.augmentation(image=image)['image']
        
        
        if self.option =='train':
            label = self.df.iloc[idx,1]
            label = torch.tensor(label, dtype=torch.int64)
            return image, label
        
        return image

# %%
class MnistModel(nn.Module):
    def __init__(self,):
        super().__init__()
        #self.conv2d = nn.Conv2d(3, 3, 3, stride=1)
        self.model = torchvision.models.resnet34(pretrained = False)
        #self.model = EfficientNet.from_name('efficientnet-b1')
        self.dropout = nn.Dropout(0.5)
        
        self.classifier = nn.Linear(1000, 10)

    def forward(self, images):
        #outputs = self.conv2d(images)
        outputs = self.model(images)
        outputs = self.dropout(outputs)
        outputs = self.classifier(outputs)
        return outputs

# %%
from sklearn.model_selection import StratifiedKFold

skf = StratifiedKFold(n_splits = 5)
folds=[]
for trn_idx,val_idx in skf.split(train['file_name'],train['label']):
    folds.append((trn_idx,val_idx))

# %%
num_epochs = 16
best_models = [] # 폴드별로 가장 validation acc가 높은 모델 저장

for i,fold in enumerate(range(5)):
    print('===============',i+1,'fold start===============')
    
    model = MnistModel().to('cuda')
    optimizer = AdamP(model.parameters(), lr=1e-3, )
    criterion = nn.CrossEntropyLoss()
    lr_scheduler = torch.optim.lr_scheduler.StepLR(optimizer,
                                                step_size = 5,
                                                gamma = 0.9)
        
    
    train_idx = folds[fold][0]
    valid_idx = folds[fold][1]
    
    train_data = train.loc[trn_idx]
    val_data = train.loc[valid_idx]
    
    train_transforms = A.Compose([
    A.Normalize(),
    A.HorizontalFlip(),
    A.RandomRotate90(p=0.5),
    A.VerticalFlip(p=0.5),
    ToTensor()
    ])

    test_transforms = A.Compose([
        A.Normalize(),
        ToTensor()
        ])

    train_dataset = CustomDataset(train_data,'train/','train',train_transforms)
    train_loader = DataLoader(train_dataset, batch_size=64, shuffle=True, num_workers=0)

    valid_dataset = CustomDataset(val_data,'train/','train',test_transforms)
    valid_loader = DataLoader(valid_dataset, batch_size=64, shuffle=False, num_workers=0)
    
    
    valid_acc_max = 0.85
    valid_loss_min = 0.4
    for epoch in range(num_epochs):

        for i, (images, targets) in enumerate(train_loader):
            model.train()
            images, targets = images.to('cuda'), targets.to('cuda')

            optimizer.zero_grad()
            outputs = model(images)

            loss = criterion(outputs, targets)
            loss.backward()
            optimizer.step()  

            if (i+1) % 20 == 0:
                print(f'Epoch: {epoch} - Loss: {loss:.6f}')


        val_loss = []
        val_acc = []
        for i, (images, targets) in enumerate(valid_loader):
            model.eval()
            images, targets = images.to('cuda'), targets.to('cuda')

            with torch.no_grad():
                outputs = model(images)
                valid_loss = criterion(outputs,targets).cpu().detach().numpy()

                preds = torch.argmax(outputs,axis = 1)
                preds = preds.cpu().detach().numpy()

                targets = targets.cpu().detach().numpy()
                batch_acc = (preds==targets).mean()



                val_loss.append(valid_loss)
                val_acc.append(batch_acc)

        val_loss = np.mean(val_loss)
        val_acc = np.mean(val_acc)

        print(f'Epoch: {epoch} - valid Loss: {val_loss:.6f} - valid_acc : {val_acc:.6f}')
        
        '''
         if valid_acc_max < val_acc:
            valid_acc_max = val_acc
            best_models.append(model)
            print('model save, model val acc : ',val_acc)
            print('best_models size : ',len(best_models))
            '''


        if valid_loss_min > val_loss:
            valid_loss_min = val_loss
            best_models.append(model)
            
    # Learning rate 조절
    lr_scheduler.step()
# Out:
# =============== 1 fold start===============
# Epoch: 0 - Loss: 2.027545
# Epoch: 0 - Loss: 1.299201
# Epoch: 0 - Loss: 1.288974
# Epoch: 0 - valid Loss: 1.580606 - valid_acc : 0.540820
# Epoch: 1 - Loss: 1.208633
# Epoch: 1 - Loss: 0.998218
# Epoch: 1 - Loss: 1.078507
# Epoch: 1 - valid Loss: 0.956541 - valid_acc : 0.649609
# Epoch: 2 - Loss: 0.763615
# Epoch: 2 - Loss: 0.757862
# Epoch: 2 - Loss: 0.787007
# Epoch: 2 - valid Loss: 0.842701 - valid_acc : 0.709375
# Epoch: 3 - Loss: 0.722738
# Epoch: 3 - Loss: 0.806212
# Epoch: 3 - Loss: 0.758249
# Epoch: 3 - valid Loss: 0.418378 - valid_acc : 0.872070
# Epoch: 4 - Loss: 1.025948
# Epoch: 4 - Loss: 0.667193
# Epoch: 4 - Loss: 0.514454
# Epoch: 4 - valid Loss: 0.415807 - valid_acc : 0.851953
# Epoch: 5 - Loss: 0.468797
# Epoch: 5 - Loss: 0.390045
# Epoch: 5 - Loss: 0.435537
# Epoch: 5 - valid Loss: 0.634373 - valid_acc : 0.768164
# Epoch: 6 - Loss: 0.312579
# Epoch: 6 - Loss: 0.278234
# Epoch: 6 - Loss: 0.337076
# Epoch: 6 - valid Loss: 0.354196 - valid_acc : 0.897461
# Epoch: 7 - Loss: 0.384503
# Epoch: 7 - Loss: 0.713508
# Epoch: 7 - Loss: 0.423419
# Epoch: 7 - valid Loss: 0.251945 - valid_acc : 0.917969
# Epoch: 8 - Loss: 0.416555
# Epoch: 8 - Loss: 0.415526
# Epoch: 8 - Loss: 0.406801
# Epoch: 8 - valid Loss: 0.396758 - valid_acc : 0.874023
# Epoch: 9 - Loss: 0.267003
# Epoch: 9 - Loss: 0.301769
# Epoch: 9 - Loss: 0.424508
# Epoch: 9 - valid Loss: 0.279935 - valid_acc : 0.913281
# Epoch: 10 - Loss: 0.380876
# Epoch: 10 - Loss: 0.398121
# Epoch: 10 - Loss: 0.399950
# Epoch: 10 - valid Loss: 0.501500 - valid_acc : 0.850000
# Epoch: 11 - Loss: 0.314801
# Epoch: 11 - Loss: 0.246430
# Epoch: 11 - Loss: 0.204352
# Epoch: 11 - valid Loss: 0.216869 - valid_acc : 0.928516
# Epoch: 12 - Loss: 0.290034
# Epoch: 12 - Loss: 0.300492
# Epoch: 12 - Loss: 0.323996
# Epoch: 12 - valid Loss: 0.267866 - valid_acc : 0.920898
# Epoch: 13 - Loss: 0.288426
# Epoch: 13 - Loss: 0.421509
# Epoch: 13 - Loss: 0.323913
# Epoch: 13 - valid Loss: 0.244939 - valid_acc : 0.927734
# Epoch: 14 - Loss: 0.553061
# Epoch: 14 - Loss: 0.131531
# Epoch: 14 - Loss: 0.228764
# Epoch: 14 - valid Loss: 0.187671 - valid_acc : 0.945703
# Epoch: 15 - Loss: 0.076618
# Epoch: 15 - Loss: 0.309357
# Epoch: 15 - Loss: 0.153406
# Epoch: 15 - valid Loss: 0.111264 - valid_acc : 0.966211
# =============== 2 fold start===============
# Epoch: 0 - Loss: 1.196577
# Epoch: 0 - Loss: 1.838599
# Epoch: 0 - Loss: 1.201364
# Epoch: 0 - valid Loss: 1.920481 - valid_acc : 0.466211
# Epoch: 1 - Loss: 0.952987
# Epoch: 1 - Loss: 0.995301
# Epoch: 1 - Loss: 0.351538
# Epoch: 1 - valid Loss: 2.096853 - valid_acc : 0.517383
# Epoch: 2 - Loss: 1.024560
# Epoch: 2 - Loss: 0.680299
# Epoch: 2 - Loss: 0.539941
# Epoch: 2 - valid Loss: 1.679457 - valid_acc : 0.537305
# Epoch: 3 - Loss: 0.689258
# Epoch: 3 - Loss: 0.869889
# Epoch: 3 - Loss: 0.710112
# Epoch: 3 - valid Loss: 0.810746 - valid_acc : 0.733789
# Epoch: 4 - Loss: 0.546271
# Epoch: 4 - Loss: 0.602829
# Epoch: 4 - Loss: 0.821802
# Epoch: 4 - valid Loss: 0.763515 - valid_acc : 0.756250
# Epoch: 5 - Loss: 0.384439
# Epoch: 5 - Loss: 0.394821
# Epoch: 5 - Loss: 0.495300
# Epoch: 5 - valid Loss: 0.455762 - valid_acc : 0.853125
# Epoch: 6 - Loss: 0.476967
# Epoch: 6 - Loss: 0.504582
# Epoch: 6 - Loss: 0.304217
# Epoch: 6 - valid Loss: 0.276937 - valid_acc : 0.909766
# Epoch: 7 - Loss: 0.534075
# Epoch: 7 - Loss: 0.377025
# Epoch: 7 - Loss: 0.241678
# Epoch: 7 - valid Loss: 0.323082 - valid_acc : 0.895508
# Epoch: 8 - Loss: 0.367921
# Epoch: 8 - Loss: 0.239319
# Epoch: 8 - Loss: 0.242095
# Epoch: 8 - valid Loss: 0.485653 - valid_acc : 0.845508
# Epoch: 9 - Loss: 0.083181
# Epoch: 9 - Loss: 0.498041
# Epoch: 9 - Loss: 0.435240
# Epoch: 9 - valid Loss: 0.332521 - valid_acc : 0.896484
# Epoch: 10 - Loss: 0.306686
# Epoch: 10 - Loss: 0.123675
# Epoch: 10 - Loss: 0.287085
# Epoch: 10 - valid Loss: 0.224461 - valid_acc : 0.928711
# Epoch: 11 - Loss: 0.338772
# Epoch: 11 - Loss: 0.169423
# Epoch: 11 - Loss: 0.431211
# Epoch: 11 - valid Loss: 0.223803 - valid_acc : 0.922266
# Epoch: 12 - Loss: 0.194901
# Epoch: 12 - Loss: 0.224535
# Epoch: 12 - Loss: 0.421075
# Epoch: 12 - valid Loss: 0.485840 - valid_acc : 0.848828
# Epoch: 13 - Loss: 0.718060
# Epoch: 13 - Loss: 0.116408
# Epoch: 13 - Loss: 0.352135
# Epoch: 13 - valid Loss: 0.211978 - valid_acc : 0.929883
# Epoch: 14 - Loss: 0.319260
# Epoch: 14 - Loss: 0.242666
# Epoch: 14 - Loss: 0.253942
# Epoch: 14 - valid Loss: 0.537433 - valid_acc : 0.822852
# Epoch: 15 - Loss: 0.507822
# Epoch: 15 - Loss: 0.185814
# Epoch: 15 - Loss: 0.201305
# Epoch: 15 - valid Loss: 0.151579 - valid_acc : 0.944531
# =============== 3 fold start===============
# Epoch: 0 - Loss: 1.767820
# Epoch: 0 - Loss: 1.420046
# Epoch: 0 - Loss: 1.689836
# Epoch: 0 - valid Loss: 4.045250 - valid_acc : 0.172852
# Epoch: 1 - Loss: 0.963058
# Epoch: 1 - Loss: 0.918392
# Epoch: 1 - Loss: 1.042359
# Epoch: 1 - valid Loss: 1.290554 - valid_acc : 0.592187
# Epoch: 2 - Loss: 0.581679
# Epoch: 2 - Loss: 0.651233
# Epoch: 2 - Loss: 0.690506
# Epoch: 2 - valid Loss: 0.536358 - valid_acc : 0.799023
# Epoch: 3 - Loss: 0.970930
# Epoch: 3 - Loss: 0.685150
# Epoch: 3 - Loss: 0.688665
# Epoch: 3 - valid Loss: 0.832021 - valid_acc : 0.716602
# Epoch: 4 - Loss: 0.786649
# Epoch: 4 - Loss: 0.687563
# Epoch: 4 - Loss: 0.400427
# Epoch: 4 - valid Loss: 0.637851 - valid_acc : 0.777148
# Epoch: 5 - Loss: 0.651030
# Epoch: 5 - Loss: 0.502366
# Epoch: 5 - Loss: 0.608616
# Epoch: 5 - valid Loss: 0.955550 - valid_acc : 0.703906
# Epoch: 6 - Loss: 0.533069
# Epoch: 6 - Loss: 0.314882
# Epoch: 6 - Loss: 0.319440
# Epoch: 6 - valid Loss: 0.264379 - valid_acc : 0.912695
# Epoch: 7 - Loss: 0.545160
# Epoch: 7 - Loss: 0.772829
# Epoch: 7 - Loss: 0.489400
# Epoch: 7 - valid Loss: 0.319190 - valid_acc : 0.896875
# Epoch: 8 - Loss: 0.309703
# Epoch: 8 - Loss: 0.426204
# Epoch: 8 - Loss: 0.398957
# Epoch: 8 - valid Loss: 0.370959 - valid_acc : 0.880664
# Epoch: 9 - Loss: 0.219187
# Epoch: 9 - Loss: 0.375581
# Epoch: 9 - Loss: 0.234580
# Epoch: 9 - valid Loss: 0.411108 - valid_acc : 0.878320
# Epoch: 10 - Loss: 0.208028
# Epoch: 10 - Loss: 0.368111
# Epoch: 10 - Loss: 0.419641
# Epoch: 10 - valid Loss: 0.586971 - valid_acc : 0.804492
# Epoch: 11 - Loss: 0.359678
# Epoch: 11 - Loss: 0.197370
# Epoch: 11 - Loss: 0.193010
# Epoch: 11 - valid Loss: 0.219217 - valid_acc : 0.924219
# Epoch: 12 - Loss: 0.443172
# Epoch: 12 - Loss: 0.253970
# Epoch: 12 - Loss: 0.219923
# Epoch: 12 - valid Loss: 0.890681 - valid_acc : 0.830078
# Epoch: 13 - Loss: 0.187867
# Epoch: 13 - Loss: 0.328251
# Epoch: 13 - Loss: 0.281035
# Epoch: 13 - valid Loss: 0.164426 - valid_acc : 0.946484
# Epoch: 14 - Loss: 0.391203
# Epoch: 14 - Loss: 0.241053
# Epoch: 14 - Loss: 0.216035
# Epoch: 14 - valid Loss: 0.190128 - valid_acc : 0.942773
# Epoch: 15 - Loss: 0.222136
# Epoch: 15 - Loss: 0.334739
# Epoch: 15 - Loss: 0.274174
# Epoch: 15 - valid Loss: 0.332809 - valid_acc : 0.897656
# =============== 4 fold start===============
# Epoch: 0 - Loss: 1.767700
# Epoch: 0 - Loss: 1.682356
# Epoch: 0 - Loss: 0.891029
# Epoch: 0 - valid Loss: 3.877272 - valid_acc : 0.385156
# Epoch: 1 - Loss: 1.178308
# Epoch: 1 - Loss: 0.886557
# Epoch: 1 - Loss: 1.288175
# Epoch: 1 - valid Loss: 2.099664 - valid_acc : 0.454297
# Epoch: 2 - Loss: 0.816749
# Epoch: 2 - Loss: 0.815563
# Epoch: 2 - Loss: 0.984425
# Epoch: 2 - valid Loss: 1.250905 - valid_acc : 0.608789
# Epoch: 3 - Loss: 0.663479

# %%
test_transforms = A.Compose([
    A.Normalize(),
    ToTensor()
])

test_dataset = CustomDataset(test,'test/test','test',test_transforms)
test_loader = DataLoader(test_dataset, batch_size=64, shuffle=False, num_workers=0)

# %%
len(best_models)
# Out:
# 24

# %%
preds = []
for idx,model in enumerate(best_models): 
    print(idx+1, '번째 모델 예측 진행중')
    model = model
    model.eval()
    y_pred = []
    with torch.no_grad():
        for i, d in enumerate(test_loader):
            inputs = d.to('cuda')
            outputs = model(inputs).detach().cpu().numpy()
            y_pred.extend(outputs.argmax(axis=1).astype(int))
            
    preds.append(y_pred)
# Out:
# 1 번째 모델 예측 진행중
# 2 번째 모델 예측 진행중
# 3 번째 모델 예측 진행중
# 4 번째 모델 예측 진행중
# 5 번째 모델 예측 진행중
# 6 번째 모델 예측 진행중
# 7 번째 모델 예측 진행중
# 8 번째 모델 예측 진행중
# 9 번째 모델 예측 진행중
# 10 번째 모델 예측 진행중
# 11 번째 모델 예측 진행중
# 12 번째 모델 예측 진행중
# 13 번째 모델 예측 진행중
# 14 번째 모델 예측 진행중
# 15 번째 모델 예측 진행중
# 16 번째 모델 예측 진행중
# 17 번째 모델 예측 진행중
# 18 번째 모델 예측 진행중
# 19 번째 모델 예측 진행중
# 20 번째 모델 예측 진행중
# 21 번째 모델 예측 진행중
# 22 번째 모델 예측 진행중
# 23 번째 모델 예측 진행중
# 24 번째 모델 예측 진행중

# %%
from collections import Counter
np_pred = np.array(preds).T

pred = []
for i in range(5000):
    cnt = Counter(np_pred[i])
    pred.append(cnt.most_common()[0][0])
pred
# Out:
# [1,
#  0,
#  8,
#  3,
#  5,
#  9,
#  2,
#  4,
#  5,
#  4,
#  8,
#  7,
#  2,
#  4,
#  3,
#  6,
#  6,
#  5,
#  6,
#  6,
#  4,
#  0,
#  4,
#  4,
#  2,
#  7,
#  2,
#  0,
#  1,
#  4,
#  7,
#  3,
#  8,
#  2,
#  9,
#  3,
#  5,
#  6,
#  1,
#  9,
#  1,
#  6,
#  7,
#  8,
#  6,
#  3,
#  3,
#  3,
#  2,
#  8,
#  0,
#  1,
#  0,
#  5,
#  6,
#  6,
#  0,
#  3,
#  6,
#  0,
#  5,
#  9,
#  8,
#  8,
#  6,
#  2,
#  5,
#  7,
#  8,
#  2,
#  1,
#  1,
#  3,
#  8,
#  1,
#  2,
#  9,
#  8,
#  8,
#  2,
#  5,
#  5,
#  3,
#  8,
#  9,
#  9,
#  2,
#  4,
#  6,
#  6,
#  4,
#  7,
#  7,
#  3,
#  3,
#  4,
#  5,
#  5,
#  0,
#  6,
#  8,
#  7,
#  1,
#  5,
#  0,
#  6,
#  7,
#  9,
#  5,
#  0,
#  9,
#  9,
#  4,
#  0,
#  7,
#  3,
#  1,
#  0,
#  4,
#  7,
#  2,
#  6,
#  7,
#  9,
#  6,
#  1,
#  9,
#  7,
#  3,
#  2,
#  2,
#  4,
#  7,
#  3,
#  6,
#  5,
#  8,
#  3,
#  1,
#  0,
#  4,
#  5,
#  5,
#  1,
#  7,
#  4,
#  1,
#  5,
#  2,
#  0,
#  9,
#  9,
#  2,
#  0,
#  7,
#  5,
#  1,
#  4,
#  3,
#  9,
#  4,
#  8,
#  6,
#  6,
#  6,
#  6,
#  3,
#  3,
#  7,
#  1,
#  4,
#  8,
#  5,
#  7,
#  3,
#  3,
#  2,
#  7,
#  6,
#  8,
#  8,
#  6,
#  7,
#  8,
#  8,
#  4,
#  3,
#  1,
#  5,
#  7,
#  2,
#  4,
#  5,
#  4,
#  6,
#  4,
#  1,
#  2,
#  2,
#  4,
#  1,
#  4,
#  1,
#  3,
#  6,
#  8,
#  3,
#  3,
#  1,
#  8,
#  3,
#  6,
#  5,
#  0,
#  2,
#  8,
#  6,
#  4,
#  1,
#  0,
#  2,
#  0,
#  5,
#  9,
#  1,
#  7,
#  9,
#  8,
#  9,
#  1,
#  1,
#  2,
#  3,
#  3,
#  5,
#  0,
#  7,
#  7,
#  1,
#  5,
#  2,
#  6,
#  9,
#  3,
#  1,
#  1,
#  3,
#  7,
#  7,
#  6,
#  0,
#  4,
#  7,
#  9,
#  2,
#  6,
#  5,
#  3,
#  2,
#  1,
#  4,
#  1,
#  2,
#  6,
#  1,
#  9,
#  3,
#  7,
#  2,
#  3,
#  9,
#  6,
#  7,
#  7,
#  1,
#  2,
#  6,
#  4,
#  1,
#  5,
#  4,
#  7,
#  6,
#  4,
#  6,
#  1,
#  7,
#  7,
#  4,
#  9,
#  2,
#  0,
#  7,
#  5,
#  2,
#  8,
#  0,
#  2,
#  9,
#  0,
#  8,
#  9,
#  6,
#  7,
#  7,
#  3,
#  7,
#  5,
#  5,
#  6,
#  6,
#  0,
#  2,
#  4,
#  7,
#  7,
#  0,
#  6,
#  6,
#  7,
#  9,
#  6,
#  4,
#  2,
#  1,
#  1,
#  0,
#  4,
#  6,
#  5,
#  5,
#  8,
#  1,
#  3,
#  7,
#  5,
#  9,
#  5,
#  1,
#  5,
#  3,
#  3,
#  2,
#  6,
#  9,
#  6,
#  9,
#  2,
#  2,
#  8,
#  7,
#  6,
#  2,
#  7,
#  9,
#  8,
#  6,
#  2,
#  6,
#  7,
#  5,
#  9,
#  0,
#  8,
#  5,
#  5,
#  9,
#  3,
#  7,
#  4,
#  8,
#  1,
#  0,
#  8,
#  8,
#  9,
#  7,
#  5,
#  8,
#  9,
#  6,
#  2,
#  6,
#  8,
#  6,
#  6,
#  0,
#  5,
#  4,
#  2,
#  4,
#  1,
#  9,
#  9,
#  0,
#  4,
#  6,
#  9,
#  2,
#  8,
#  6,
#  4,
#  4,
#  3,
#  1,
#  3,
#  8,
#  5,
#  3,
#  0,
#  2,
#  1,
#  8,
#  8,
#  3,
#  8,
#  5,
#  1,
#  1,
#  0,
#  8,
#  5,
#  0,
#  3,
#  1,
#  4,
#  4,
#  7,
#  9,
#  5,
#  0,
#  3,
#  3,
#  2,
#  1,
#  9,
#  0,
#  2,
#  7,
#  4,
#  4,
#  9,
#  9,
#  0,
#  1,
#  4,
#  3,
#  7,
#  2,
#  8,
#  8,
#  1,
#  5,
#  4,
#  2,
#  3,
#  4,
#  0,
#  7,
#  4,
#  8,
#  4,
#  2,
#  3,
#  3,
#  1,
#  8,
#  2,
#  5,
#  4,
#  2,
#  2,
#  9,
#  4,
#  0,
#  1,
#  9,
#  1,
#  5,
#  9,
#  6,
#  2,
#  5,
#  6,
#  5,
#  0,
#  7,
#  0,
#  9,
#  5,
#  1,
#  4,
#  1,
#  6,
#  9,
#  2,
#  9,
#  9,
#  4,
#  7,
#  8,
#  2,
#  7,
#  3,
#  1,
#  3,
#  9,
#  1,
#  4,
#  6,
#  2,
#  9,
#  7,
#  9,
#  2,
#  3,
#  4,
#  2,
#  1,
#  2,
#  7,
#  1,
#  6,
#  4,
#  9,
#  1,
#  5,
#  6,
#  4,
#  7,
#  7,
#  3,
#  6,
#  5,
#  6,
#  0,
#  3,
#  6,
#  0,
#  5,
#  1,
#  6,
#  2,
#  3,
#  2,
#  7,
#  6,
#  4,
#  2,
#  0,
#  9,
#  5,
#  2,
#  3,
#  8,
#  3,
#  8,
#  9,
#  3,
#  0,
#  0,
#  3,
#  5,
#  8,
#  2,
#  9,
#  8,
#  7,
#  5,
#  4,
#  1,
#  2,
#  2,
#  3,
#  9,
#  0,
#  0,
#  7,
#  2,
#  1,
#  7,
#  1,
#  8,
#  2,
#  8,
#  0,
#  3,
#  7,
#  9,
#  6,
#  8,
#  6,
#  4,
#  6,
#  9,
#  2,
#  6,
#  9,
#  5,
#  7,
#  7,
#  9,
#  8,
#  9,
#  3,
#  8,
#  2,
#  2,
#  6,
#  0,
#  8,
#  4,
#  7,
#  8,
#  7,
#  7,
#  7,
#  8,
#  7,
#  8,
#  8,
#  8,
#  2,
#  8,
#  5,
#  5,
#  4,
#  9,
#  2,
#  3,
#  2,
#  0,
#  9,
#  1,
#  6,
#  9,
#  2,
#  3,
#  3,
#  1,
#  7,
#  6,
#  2,
#  9,
#  0,
#  3,
#  3,
#  1,
#  7,
#  4,
#  8,
#  3,
#  2,
#  4,
#  7,
#  7,
#  0,
#  0,
#  1,
#  8,
#  3,
#  6,
#  0,
#  6,
#  3,
#  3,
#  1,
#  7,
#  5,
#  4,
#  1,
#  3,
#  9,
#  1,
#  9,
#  8,
#  7,
#  7,
#  8,
#  2,
#  1,
#  4,
#  8,
#  4,
#  3,
#  4,
#  0,
#  0,
#  0,
#  5,
#  5,
#  0,
#  9,
#  7,
#  2,
#  4,
#  3,
#  3,
#  6,
#  6,
#  3,
#  0,
#  7,
#  2,
#  7,
#  1,
#  4,
#  9,
#  2,
#  6,
#  6,
#  0,
#  0,
#  3,
#  9,
#  6,
#  3,
#  3,
#  5,
#  5,
#  6,
#  3,
#  3,
#  3,
#  4,
#  0,
#  6,
#  5,
#  5,
#  7,
#  7,
#  6,
#  0,
#  0,
#  9,
#  1,
#  1,
#  9,
#  3,
#  5,
#  7,
#  0,
#  9,
#  8,
#  1,
#  7,
#  3,
#  0,
#  0,
#  6,
#  3,
#  6,
#  7,
#  1,
#  4,
#  1,
#  1,
#  7,
#  0,
#  6,
#  3,
#  4,
#  2,
#  2,
#  2,
#  0,
#  5,
#  1,
#  9,
#  0,
#  3,
#  7,
#  1,
#  1,
#  6,
#  5,
#  5,
#  7,
#  2,
#  0,
#  1,
#  6,
#  6,
#  2,
#  1,
#  0,
#  1,
#  3,
#  0,
#  2,
#  3,
#  0,
#  1,
#  2,
#  2,
#  7,
#  5,
#  2,
#  7,
#  0,
#  1,
#  0,
#  2,
#  1,
#  1,
#  7,
#  0,
#  1,
#  3,
#  3,
#  1,
#  7,
#  2,
#  6,
#  2,
#  2,
#  0,
#  3,
#  3,
#  7,
#  6,
#  2,
#  0,
#  5,
#  9,
#  7,
#  6,
#  6,
#  7,
#  0,
#  0,
#  2,
#  3,
#  1,
#  3,
#  9,
#  0,
#  2,
#  6,
#  0,
#  6,
#  6,
#  5,
#  6,
#  5,
#  0,
#  5,
#  0,
#  4,
#  2,
#  3,
#  7,
#  1,
#  0,
#  7,
#  3,
#  5,
#  6,
#  2,
#  2,
#  5,
#  1,
#  4,
#  2,
#  2,
#  4,
#  6,
#  3,
#  4,
#  2,
#  1,
#  8,
#  7,
#  7,
#  4,
#  1,
#  3,
#  1,
#  7,
#  2,
#  6,
#  6,
#  4,
#  3,
#  4,
#  1,
#  3,
#  7,
#  4,
#  1,
#  1,
#  0,
#  4,
#  2,
#  7,
#  3,
#  2,
#  0,
#  0,
#  3,
#  1,
#  4,
#  2,
#  3,
#  4,
#  6,
#  3,
#  4,
#  6,
#  2,
#  5,
#  3,
#  4,
#  3,
#  1,
#  2,
#  1,
#  1,
#  6,
#  6,
#  6,
#  5,
#  2,
#  1,
#  6,
#  2,
#  1,
#  4,
#  4,
#  1,
#  6,
#  3,
#  2,
#  1,
#  6,
#  7,
#  7,
#  0,
#  5,
#  3,
#  0,
#  2,
#  4,
#  2,
#  4,
#  1,
#  7,
#  4,
#  0,
#  5,
#  5,
#  3,
#  4,
#  6,
#  5,
#  7,
#  6,
#  7,
#  5,
#  5,
#  6,
#  3,
#  5,
#  3,
#  0,
#  1,
#  3,
#  0,
#  2,
#  7,
#  0,
#  0,
#  2,
#  3,
#  1,
#  4,
#  6,
#  7,
#  2,
#  4,
#  5,
#  1,
#  0,
#  6,
#  6,
#  4,
#  3,
#  4,
#  4,
#  5,
#  0,
#  1,
#  1,
#  6,
#  7,
#  2,
#  4,
#  5,
#  6,
#  5,
#  ...]

# %%
submission = pd.read_csv('sample_submission.csv')
submission['label'] = pred

# %%
submission.to_csv('sub_211123.csv',index = False)

# %%
submission['label'].value_counts()
# Out:
# 6    592
# 7    569
# 5    557
# 3    498
# 2    491
# 8    484
# 0    478
# 4    467
# 1    461
# 9    403
# Name: label, dtype: int64
