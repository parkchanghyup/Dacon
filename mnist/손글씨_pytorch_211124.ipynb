# %%
torch.__version__
# Out:
# '1.10.0+cu102'

# %%
import warnings
warnings.filterwarnings(action='ignore')

import os
import pandas as pd
import numpy as np

from PIL import Image
import matplotlib.pyplot as plt
# %matplotlib inline

from sklearn.model_selection import train_test_split
import IPython.display as ipd
import time

# %%
import torch
import torchvision
from torch import Tensor, nn, optim
from torch.utils.data import Dataset, DataLoader

import torch.nn.functional as F
import torch.nn as nn
import torchvision.transforms as transforms
import torchvision.models as models
from adamp import AdamP
from torchsummary import summary

import albumentations as A
from albumentations.pytorch import ToTensor
from efficientnet_pytorch import EfficientNet

# %% [markdown]
# ## 시드 고정

# %%
import random
def seed_everything(seed: int = 42):
    random.seed(seed)
    np.random.seed(seed)
    os.environ["PYTHONHASHSEED"] = str(seed)
    torch.manual_seed(seed)
    torch.cuda.manual_seed(seed)  
    torch.backends.cudnn.deterministic = True  
    torch.backends.cudnn.benchmark = True  
seed_everything()

# %% [markdown]
# ## 데이터 불러오기

# %%
train = pd.read_csv('./train/train_data.csv')
test = pd.read_csv('./test/test/test_data.csv')

# %%
train.columns = ['file_name','label']

# %%
train.head()
# Out:
#        file_name  label
# 0  train0001.png      8
# 1  train0002.png      8
# 2  train0003.png      8
# 3  train0004.png      8
# 4  train0005.png      8

# %%
test.head()
# Out:
#      file_name
# 0  idx0001.png
# 1  idx0002.png
# 2  idx0003.png
# 3  idx0004.png
# 4  idx0005.png

# %%
class CustomDataset(torch.utils.data.Dataset): 
    def __init__(self,df,path,option,augmentation=None):
        self.df = df
        self.option = option
        self.augmentation = augmentation
        self.path = path

    def __len__(self):
        return len(self.df)
    
    def __getitem__(self, idx): 
        file_path  = self.df.iloc[idx,0]
        image=  Image.open(os.path.join(self.path,file_path)).convert('RGB')
        #image = image.resize((100,100))
        image = np.array(image)
        
        #image = transforms.ToTensor()(image=image)['image']
        
        
        if self.augmentation is not None:
            image = self.augmentation(image=image)['image']
        
        
        if self.option =='train':
            label = self.df.iloc[idx,1]
            label = torch.tensor(label, dtype=torch.int64)
            return image, label
        
        return image

# %%
class CNN(torch.nn.Module):

    def __init__(self):
        super(CNN, self).__init__()
        # 첫번째층
        # ImgIn shape=(batch_size, 28, 28, 2)
        #    Conv     -> (batch_size, 28, 28, 16)
        self.layer1 = torch.nn.Sequential(
            torch.nn.Conv2d(3, 16, kernel_size=3, stride=1, padding='same'),
            torch.nn.ReLU(),
            torch.nn.BatchNorm2d(16),
            torch.nn.Dropout(p=0.3))
        
        # 두번째층
        # ImgIn shape=(batch_size, 28, 28, 16)
        #    Conv      ->(batch_size, 28, 28, 32)
        #    Pool      ->(batch_size, 9, 9, 32)
        self.layer2 = torch.nn.Sequential(
            torch.nn.Conv2d(16, 32, kernel_size=3, stride=1, padding='same'),
            torch.nn.ReLU(),
            torch.nn.BatchNorm2d(32),
            torch.nn.Conv2d(32, 32, kernel_size=5, stride=1, padding='same'),
            torch.nn.ReLU(),
            torch.nn.BatchNorm2d(32),
            torch.nn.Conv2d(32, 32, kernel_size=5, stride=1, padding='same'),
            torch.nn.ReLU(),
            torch.nn.BatchNorm2d(32),
            torch.nn.Conv2d(32, 32, kernel_size=5, stride=1, padding='same'),
            torch.nn.ReLU(),
            torch.nn.BatchNorm2d(32),
            torch.nn.MaxPool2d(kernel_size=3, stride=3),
            torch.nn.Dropout(p=0.3))
        
        # 세번째층
        # ImgIn shape=(batch_size, 9, 9, 32)
        #    Conv      ->(batch_size, 9, 9, 64)
        #    Pool      ->(batch_size, 3, 3, 64)        
        self.layer3 = torch.nn.Sequential(
            torch.nn.Conv2d(32, 64, kernel_size=3, stride=1, padding='same'),
            torch.nn.ReLU(),
            torch.nn.BatchNorm2d(64),
            torch.nn.Conv2d(64, 64, kernel_size=3, stride=1, padding='same'),
            torch.nn.ReLU(),
            torch.nn.BatchNorm2d(64),
            torch.nn.MaxPool2d(kernel_size=3, stride=3),
            torch.nn.Dropout(p=0.3))
        
        # 전결합층 7x7x64 inputs -> 10 outputs
        self.fc = torch.nn.Linear(3*3*64, 10, bias=True)

        torch.nn.init.xavier_uniform_(self.fc.weight) # fc 가중치 초기화

    def forward(self, x):
        out = self.layer1(x)
        out = self.layer2(out)
        out = self.layer3(out)
        out = out.view(out.size(0), -1)   # Flatten
        out = self.fc(out)
        return out

# %%
class MnistModel(nn.Module):
    def __init__(self,):
        super().__init__()
        #self.conv2d = nn.Conv2d(3, 3, 3, stride=1)
        self.model = torchvision.models.resnet18(pretrained = False)
        #self.model = EfficientNet.from_name('efficientnet-b1')
        self.dropout = nn.Dropout(0.5)
        
        self.classifier = nn.Linear(1000, 10)

    def forward(self, images):
        #outputs = self.conv2d(images)
        outputs = self.model(images)
        outputs = self.dropout(outputs)
        outputs = self.classifier(outputs)
        return outputs

# %%
from sklearn.model_selection import StratifiedKFold

skf = StratifiedKFold(n_splits = 4)
folds=[]
for trn_idx,val_idx in skf.split(train['file_name'],train['label']):
    folds.append((trn_idx,val_idx))

# %%
num_epochs = 30
best_models = [] # 폴드별로 가장 validation acc가 높은 모델 저장

for i,fold in enumerate(range(4)):
    print('===============',i+1,'fold start===============')
    
    model = CNN().to('cuda')
    optimizer = AdamP(model.parameters(), lr=1e-3, )
    criterion = nn.CrossEntropyLoss()
    lr_scheduler = torch.optim.lr_scheduler.StepLR(optimizer,
                                                step_size = 5,
                                                gamma = 0.9)
        
    
    train_idx = folds[fold][0]
    valid_idx = folds[fold][1]
    
    train_data = train.loc[trn_idx]
    val_data = train.loc[valid_idx]
    
    train_transforms = A.Compose([
    A.Normalize(),
    A.HorizontalFlip(),
    A.RandomRotate90(p=0.5),
    A.VerticalFlip(p=0.5),
    ToTensor()
    ])

    test_transforms = A.Compose([
        A.Normalize(),
        ToTensor()
        ])

    train_dataset = CustomDataset(train_data,'train/','train',train_transforms)
    train_loader = DataLoader(train_dataset, batch_size=64, shuffle=True, num_workers=0)

    valid_dataset = CustomDataset(val_data,'train/','train',test_transforms)
    valid_loader = DataLoader(valid_dataset, batch_size=64, shuffle=False, num_workers=0)
    
    
    valid_acc_max = 0.85
    valid_loss_min = 0.4
    for epoch in range(num_epochs):

        for i, (images, targets) in enumerate(train_loader):
            model.train()
            images, targets = images.to('cuda'), targets.to('cuda')

            optimizer.zero_grad()
            outputs = model(images)

            loss = criterion(outputs, targets)
            loss.backward()
            optimizer.step()  

            if (i+1) % 20 == 0:
                print(f'Epoch: {epoch} - Loss: {loss:.6f}')


        val_loss = []
        val_acc = []
        for i, (images, targets) in enumerate(valid_loader):
            model.eval()
            images, targets = images.to('cuda'), targets.to('cuda')

            with torch.no_grad():
                outputs = model(images)
                valid_loss = criterion(outputs,targets).cpu().detach().numpy()

                preds = torch.argmax(outputs,axis = 1)
                preds = preds.cpu().detach().numpy()

                targets = targets.cpu().detach().numpy()
                batch_acc = (preds==targets).mean()



                val_loss.append(valid_loss)
                val_acc.append(batch_acc)

        val_loss = np.mean(val_loss)
        val_acc = np.mean(val_acc)

        print(f'Epoch: {epoch} - valid Loss: {val_loss:.6f} - valid_acc : {val_acc:.6f}')
        
        '''
         if valid_acc_max < val_acc:
            valid_acc_max = val_acc
            best_models.append(model)
            print('model save, model val acc : ',val_acc)
            print('best_models size : ',len(best_models))
            '''


        if valid_loss_min > val_loss:
            valid_loss_min = val_loss
            best_models.append(model)
            
    # Learning rate 조절
    lr_scheduler.step()
# Out:
# =============== 1 fold start===============
# Epoch: 0 - Loss: 3.040205
# Epoch: 0 - Loss: 2.497284
# Epoch: 0 - valid Loss: 1.188079 - valid_acc : 0.532858
# Epoch: 1 - Loss: 1.771061
# Epoch: 1 - Loss: 1.161166
# Epoch: 1 - valid Loss: 1.350177 - valid_acc : 0.525230
# Epoch: 2 - Loss: 1.223000
# Epoch: 2 - Loss: 1.093718
# Epoch: 2 - valid Loss: 0.548030 - valid_acc : 0.824770
# Epoch: 3 - Loss: 1.484946
# Epoch: 3 - Loss: 0.914585
# Epoch: 3 - valid Loss: 0.683577 - valid_acc : 0.780515
# Epoch: 4 - Loss: 1.182467
# Epoch: 4 - Loss: 0.908000
# Epoch: 4 - valid Loss: 0.370368 - valid_acc : 0.886719
# Epoch: 5 - Loss: 0.756857
# Epoch: 5 - Loss: 0.797708
# Epoch: 5 - valid Loss: 0.354504 - valid_acc : 0.887500
# Epoch: 6 - Loss: 0.754496
# Epoch: 6 - Loss: 0.639200
# Epoch: 6 - valid Loss: 0.323372 - valid_acc : 0.893153
# Epoch: 7 - Loss: 0.784084
# Epoch: 7 - Loss: 0.394101
# Epoch: 7 - valid Loss: 0.192939 - valid_acc : 0.939844
# Epoch: 8 - Loss: 0.468422
# Epoch: 8 - Loss: 0.294915
# Epoch: 8 - valid Loss: 0.242287 - valid_acc : 0.925092
# Epoch: 9 - Loss: 0.543010
# Epoch: 9 - Loss: 0.714402
# Epoch: 9 - valid Loss: 0.250303 - valid_acc : 0.917463
# Epoch: 10 - Loss: 0.461398
# Epoch: 10 - Loss: 0.363676
# Epoch: 10 - valid Loss: 0.166617 - valid_acc : 0.946094
# Epoch: 11 - Loss: 0.573948
# Epoch: 11 - Loss: 0.437900
# Epoch: 11 - valid Loss: 0.219155 - valid_acc : 0.931342
# Epoch: 12 - Loss: 0.641879
# Epoch: 12 - Loss: 0.443666
# Epoch: 12 - valid Loss: 0.223565 - valid_acc : 0.929779
# Epoch: 13 - Loss: 0.604341
# Epoch: 13 - Loss: 0.325989
# Epoch: 13 - valid Loss: 0.169412 - valid_acc : 0.947840
# Epoch: 14 - Loss: 0.418236
# Epoch: 14 - Loss: 0.270921
# Epoch: 14 - valid Loss: 0.178237 - valid_acc : 0.939063
# Epoch: 15 - Loss: 0.426990
# Epoch: 15 - Loss: 0.589131
# Epoch: 15 - valid Loss: 0.179247 - valid_acc : 0.940028
# Epoch: 16 - Loss: 0.424737
# Epoch: 16 - Loss: 0.348711
# Epoch: 16 - valid Loss: 0.144149 - valid_acc : 0.956250
# Epoch: 17 - Loss: 0.261349
# Epoch: 17 - Loss: 0.265250
# Epoch: 17 - valid Loss: 0.141346 - valid_acc : 0.951746
# Epoch: 18 - Loss: 0.265069
# Epoch: 18 - Loss: 0.368273
# Epoch: 18 - valid Loss: 0.164498 - valid_acc : 0.953217
# Epoch: 19 - Loss: 0.537074
# Epoch: 19 - Loss: 0.430406
# Epoch: 19 - valid Loss: 0.121760 - valid_acc : 0.966406
# Epoch: 20 - Loss: 0.259131
# Epoch: 20 - Loss: 0.404151
# Epoch: 20 - valid Loss: 0.140046 - valid_acc : 0.956250
# Epoch: 21 - Loss: 0.401138
# Epoch: 21 - Loss: 0.206288
# Epoch: 21 - valid Loss: 0.147927 - valid_acc : 0.953906
# Epoch: 22 - Loss: 0.268489
# Epoch: 22 - Loss: 0.450089
# Epoch: 22 - valid Loss: 0.128735 - valid_acc : 0.960156
# Epoch: 23 - Loss: 0.243688
# Epoch: 23 - Loss: 0.147615
# Epoch: 23 - valid Loss: 0.139941 - valid_acc : 0.949403
# Epoch: 24 - Loss: 0.219163
# Epoch: 24 - Loss: 0.239597
# Epoch: 24 - valid Loss: 0.166521 - valid_acc : 0.945404
# Epoch: 25 - Loss: 0.213035
# Epoch: 25 - Loss: 0.243779
# Epoch: 25 - valid Loss: 0.111460 - valid_acc : 0.964936
# Epoch: 26 - Loss: 0.470593
# Epoch: 26 - Loss: 0.294126
# Epoch: 26 - valid Loss: 0.084575 - valid_acc : 0.976562
# Epoch: 27 - Loss: 0.134913
# Epoch: 27 - Loss: 0.302431
# Epoch: 27 - valid Loss: 0.114933 - valid_acc : 0.962592
# Epoch: 28 - Loss: 0.274774
# Epoch: 28 - Loss: 0.241223
# Epoch: 28 - valid Loss: 0.103782 - valid_acc : 0.967279
# Epoch: 29 - Loss: 0.237432
# Epoch: 29 - Loss: 0.211999
# Epoch: 29 - valid Loss: 0.125065 - valid_acc : 0.959467
# =============== 2 fold start===============
# Epoch: 0 - Loss: 2.518393
# Epoch: 0 - Loss: 2.049386
# Epoch: 0 - valid Loss: 1.298608 - valid_acc : 0.548392
# Epoch: 1 - Loss: 1.608544
# Epoch: 1 - Loss: 1.611350
# Epoch: 1 - valid Loss: 0.961041 - valid_acc : 0.705055
# Epoch: 2 - Loss: 1.207326
# Epoch: 2 - Loss: 1.647869
# Epoch: 2 - valid Loss: 0.706574 - valid_acc : 0.779090
# Epoch: 3 - Loss: 0.971489
# Epoch: 3 - Loss: 0.950835
# Epoch: 3 - valid Loss: 0.579605 - valid_acc : 0.803768
# Epoch: 4 - Loss: 1.036638
# Epoch: 4 - Loss: 0.896976
# Epoch: 4 - valid Loss: 0.998952 - valid_acc : 0.744991
# Epoch: 5 - Loss: 0.795053
# Epoch: 5 - Loss: 0.834993
# Epoch: 5 - valid Loss: 0.606404 - valid_acc : 0.821186
# Epoch: 6 - Loss: 0.613952
# Epoch: 6 - Loss: 0.681053
# Epoch: 6 - valid Loss: 0.320685 - valid_acc : 0.897151
# Epoch: 7 - Loss: 0.514294
# Epoch: 7 - Loss: 0.517681
# Epoch: 7 - valid Loss: 0.452299 - valid_acc : 0.859651
# Epoch: 8 - Loss: 0.698176
# Epoch: 8 - Loss: 0.487334
# Epoch: 8 - valid Loss: 0.356769 - valid_acc : 0.884053
# Epoch: 9 - Loss: 0.681315
# Epoch: 9 - Loss: 0.356324
# Epoch: 9 - valid Loss: 0.336547 - valid_acc : 0.897151
# Epoch: 10 - Loss: 0.785653
# Epoch: 10 - Loss: 0.361747
# Epoch: 10 - valid Loss: 0.245315 - valid_acc : 0.923621
# Epoch: 11 - Loss: 0.662625
# Epoch: 11 - Loss: 0.437671
# Epoch: 11 - valid Loss: 0.262384 - valid_acc : 0.920496
# Epoch: 12 - Loss: 0.250554
# Epoch: 12 - Loss: 0.445400
# Epoch: 12 - valid Loss: 0.301297 - valid_acc : 0.911903
# Epoch: 13 - Loss: 0.320927
# Epoch: 13 - Loss: 0.418590
# Epoch: 13 - valid Loss: 0.261058 - valid_acc : 0.918750
# Epoch: 14 - Loss: 0.351935
# Epoch: 14 - Loss: 0.239979
# Epoch: 14 - valid Loss: 0.239205 - valid_acc : 0.925965
# Epoch: 15 - Loss: 0.458474
# Epoch: 15 - Loss: 0.275649
# Epoch: 15 - valid Loss: 0.229266 - valid_acc : 0.933686
# Epoch: 16 - Loss: 0.292461
# Epoch: 16 - Loss: 0.416634
# Epoch: 16 - valid Loss: 0.228193 - valid_acc : 0.931342
# Epoch: 17 - Loss: 0.304167
# Epoch: 17 - Loss: 0.203106
# Epoch: 17 - valid Loss: 0.180799 - valid_acc : 0.948529
# Epoch: 18 - Loss: 0.266382
# Epoch: 18 - Loss: 0.225479
# Epoch: 18 - valid Loss: 0.178766 - valid_acc : 0.948529
# Epoch: 19 - Loss: 0.286700
# Epoch: 19 - Loss: 0.314658
# Epoch: 19 - valid Loss: 0.253439 - valid_acc : 0.907215
# Epoch: 20 - Loss: 0.278850
# Epoch: 20 - Loss: 0.208269
# Epoch: 20 - valid Loss: 0.148872 - valid_acc : 0.947748
# Epoch: 21 - Loss: 0.308541
# Epoch: 21 - Loss: 0.296890
# Epoch: 21 - valid Loss: 0.181094 - valid_acc : 0.939936
# Epoch: 22 - Loss: 0.305908
# Epoch: 22 - Loss: 0.233362
# Epoch: 22 - valid Loss: 0.239215 - valid_acc : 0.920404
# Epoch: 23 - Loss: 0.219127
# Epoch: 23 - Loss: 0.238974
# Epoch: 23 - valid Loss: 0.170329 - valid_acc : 0.947748
# Epoch: 24 - Loss: 0.303650
# Epoch: 24 - Loss: 0.236152
# Epoch: 24 - valid Loss: 0.131909 - valid_acc : 0.955561
# Epoch: 25 - Loss: 0.152675
# Epoch: 25 - Loss: 0.410464
# Epoch: 25 - valid Loss: 0.150697 - valid_acc : 0.950092
# Epoch: 26 - Loss: 0.199191
# Epoch: 26 - Loss: 0.347660
# Epoch: 26 - valid Loss: 0.140761 - valid_acc : 0.951654
# Epoch: 27 - Loss: 0.364744
# Epoch: 27 - Loss: 0.352413
# Epoch: 27 - valid Loss: 0.153633 - valid_acc : 0.950000
# Epoch: 28 - Loss: 0.263581
# Epoch: 28 - Loss: 0.165113
# Epoch: 28 - valid Loss: 0.137364 - valid_acc : 0.953998
# Epoch: 29 - Loss: 0.204859
# Epoch: 29 - Loss: 0.168143
# Epoch: 29 - valid Loss: 0.097825 - valid_acc : 0.969531
# =============== 3 fold start===============
# Epoch: 0 - Loss: 2.888410
# Epoch: 0 - Loss: 2.356464
# Epoch: 0 - valid Loss: 1.260669 - valid_acc : 0.565855
# Epoch: 1 - Loss: 1.619988
# Epoch: 1 - Loss: 1.889972
# Epoch: 1 - valid Loss: 0.949191 - valid_acc : 0.654779
# Epoch: 2 - Loss: 1.155860
# Epoch: 2 - Loss: 1.490292
# Epoch: 2 - valid Loss: 0.665146 - valid_acc : 0.785432
# Epoch: 3 - Loss: 1.131844
# Epoch: 3 - Loss: 1.152337
# Epoch: 3 - valid Loss: 0.858641 - valid_acc : 0.722656
# Epoch: 4 - Loss: 0.818882
# Epoch: 4 - Loss: 0.746649
# Epoch: 4 - valid Loss: 0.540415 - valid_acc : 0.814200
# Epoch: 5 - Loss: 0.605106
# Epoch: 5 - Loss: 0.696844
# Epoch: 5 - valid Loss: 0.293501 - valid_acc : 0.907996
# Epoch: 6 - Loss: 0.660569
# Epoch: 6 - Loss: 0.876896
# Epoch: 6 - valid Loss: 0.384309 - valid_acc : 0.865855
# Epoch: 7 - Loss: 0.607214
# Epoch: 7 - Loss: 0.648661
# Epoch: 7 - valid Loss: 0.284219 - valid_acc : 0.906112
# Epoch: 8 - Loss: 0.350160
# Epoch: 8 - Loss: 0.411916
# Epoch: 8 - valid Loss: 0.367184 - valid_acc : 0.872978
# Epoch: 9 - Loss: 0.629827
# Epoch: 9 - Loss: 0.798745
# Epoch: 9 - valid Loss: 0.247941 - valid_acc : 0.919991
# Epoch: 10 - Loss: 0.299501
# Epoch: 10 - Loss: 0.548820
# Epoch: 10 - valid Loss: 0.299497 - valid_acc : 0.891820
# Epoch: 11 - Loss: 0.404227
# Epoch: 11 - Loss: 0.318894
# Epoch: 11 - valid Loss: 0.236877 - valid_acc : 0.930055
# Epoch: 12 - Loss: 0.559449
# Epoch: 12 - Loss: 0.526131
# Epoch: 12 - valid Loss: 0.190766 - valid_acc : 0.939246
# Epoch: 13 - Loss: 0.661937
# Epoch: 13 - Loss: 0.348135
# Epoch: 13 - valid Loss: 0.223362 - valid_acc : 0.929963
# Epoch: 14 - Loss: 0.434393
# Epoch: 14 - Loss: 0.531257
# Epoch: 14 - valid Loss: 0.201036 - valid_acc : 0.932583
# Epoch: 15 - Loss: 0.182601
# Epoch: 15 - Loss: 0.437934
# Epoch: 15 - valid Loss: 0.258220 - valid_acc : 0.912362
# Epoch: 16 - Loss: 0.302504
# Epoch: 16 - Loss: 0.254905
# Epoch: 16 - valid Loss: 0.167141 - valid_acc : 0.949311
# Epoch: 17 - Loss: 0.459495
# Epoch: 17 - Loss: 0.381452
# Epoch: 17 - valid Loss: 0.377048 - valid_acc : 0.877711
# Epoch: 18 - Loss: 0.287173
# Epoch: 18 - Loss: 0.394419
# Epoch: 18 - valid Loss: 0.201408 - valid_acc : 0.936397
# Epoch: 19 - Loss: 0.599546
# Epoch: 19 - Loss: 0.381564
# Epoch: 19 - valid Loss: 0.175099 - valid_acc : 0.946278
# Epoch: 20 - Loss: 0.246092
# Epoch: 20 - Loss: 0.205098
# Epoch: 20 - valid Loss: 0.118686 - valid_acc : 0.966498
# Epoch: 21 - Loss: 0.451211
# Epoch: 21 - Loss: 0.189207
# Epoch: 21 - valid Loss: 0.150084 - valid_acc : 0.952619
# Epoch: 22 - Loss: 0.538810
# Epoch: 22 - Loss: 0.397204
# Epoch: 22 - valid Loss: 0.112180 - valid_acc : 0.968842
# Epoch: 23 - Loss: 0.280094
# Epoch: 23 - Loss: 0.296717
# Epoch: 23 - valid Loss: 0.159847 - valid_acc : 0.943015
# Epoch: 24 - Loss: 0.287332
# Epoch: 24 - Loss: 0.300294
# Epoch: 24 - valid Loss: 0.145762 - valid_acc : 0.954274
# Epoch: 25 - Loss: 0.282188
# Epoch: 25 - Loss: 0.288311
# Epoch: 25 - valid Loss: 0.118185 - valid_acc : 0.959559
# Epoch: 26 - Loss: 0.234779
# Epoch: 26 - Loss: 0.326041
# Epoch: 26 - valid Loss: 0.114046 - valid_acc : 0.970496
# Epoch: 27 - Loss: 0.353668
# Epoch: 27 - Loss: 0.301819
# Epoch: 27 - valid Loss: 0.109749 - valid_acc : 0.973529
# Epoch: 28 - Loss: 0.189068
# Epoch: 28 - Loss: 0.212229
# Epoch: 28 - valid Loss: 0.136682 - valid_acc : 0.951838
# Epoch: 29 - Loss: 0.233706
# Epoch: 29 - Loss: 0.227537
# Epoch: 29 - valid Loss: 0.162467 - valid_acc : 0.956434
# =============== 4 fold start===============
# Epoch: 0 - Loss: 3.255841
# Epoch: 0 - Loss: 1.945113
# Epoch: 0 - valid Loss: 1.418486 - valid_acc : 0.530285
# Epoch: 1 - Loss: 1.786996
# Epoch: 1 - Loss: 1.382389
# Epoch: 1 - valid Loss: 0.973465 - valid_acc : 0.653125
# Epoch: 2 - Loss: 1.145811
# Epoch: 2 - Loss: 1.237618
# Epoch: 2 - valid Loss: 0.771290 - valid_acc : 0.730561
# Epoch: 3 - Loss: 0.979036
# Epoch: 3 - Loss: 0.699456
# Epoch: 3 - valid Loss: 0.490203 - valid_acc : 0.844301
# Epoch: 4 - Loss: 0.662403
# Epoch: 4 - Loss: 0.760763
# Epoch: 4 - valid Loss: 0.429170 - valid_acc : 0.856020
# Epoch: 5 - Loss: 0.535719
# Epoch: 5 - Loss: 0.733397
# Epoch: 5 - valid Loss: 0.440070 - valid_acc : 0.863327
# Epoch: 6 - Loss: 0.687008
# Epoch: 6 - Loss: 0.716152
# Epoch: 6 - valid Loss: 0.311297 - valid_acc : 0.900551
# Epoch: 7 - Loss: 0.656288
# Epoch: 7 - Loss: 0.678406
# Epoch: 7 - valid Loss: 0.303688 - valid_acc : 0.896461
# Epoch: 8 - Loss: 0.462732
# Epoch: 8 - Loss: 0.300165
# Epoch: 8 - valid Loss: 0.409462 - valid_acc : 0.866360
# Epoch: 9 - Loss: 0.496104
# Epoch: 9 - Loss: 0.451812
# Epoch: 9 - valid Loss: 0.291647 - valid_acc : 0.902114
# Epoch: 10 - Loss: 0.551648
# Epoch: 10 - Loss: 0.515359
# Epoch: 10 - valid Loss: 0.300029 - valid_acc : 0.898300
# Epoch: 11 - Loss: 0.374722
# Epoch: 11 - Loss: 0.195976
# Epoch: 11 - valid Loss: 0.287938 - valid_acc : 0.901333
# Epoch: 12 - Loss: 0.307445
# Epoch: 12 - Loss: 0.361423
# Epoch: 12 - valid Loss: 0.319372 - valid_acc : 0.891958
# Epoch: 13 - Loss: 0.312010
# Epoch: 13 - Loss: 0.185360
# Epoch: 13 - valid Loss: 0.208883 - valid_acc : 0.929090
# Epoch: 14 - Loss: 0.300985
# Epoch: 14 - Loss: 0.445521
# Epoch: 14 - valid Loss: 0.258804 - valid_acc : 0.905239
# Epoch: 15 - Loss: 0.403350
# Epoch: 15 - Loss: 0.332365
# Epoch: 15 - valid Loss: 0.254351 - valid_acc : 0.903079
# Epoch: 16 - Loss: 0.307944
# Epoch: 16 - Loss: 0.366637
# Epoch: 16 - valid Loss: 0.230346 - valid_acc : 0.933088
# Epoch: 17 - Loss: 0.313558
# Epoch: 17 - Loss: 0.449900
# Epoch: 17 - valid Loss: 0.256720 - valid_acc : 0.913051
# Epoch: 18 - Loss: 0.275468
# Epoch: 18 - Loss: 0.275981
# Epoch: 18 - valid Loss: 0.206954 - valid_acc : 0.930744
# Epoch: 19 - Loss: 0.262589
# Epoch: 19 - Loss: 0.147417
# Epoch: 19 - valid Loss: 0.201236 - valid_acc : 0.931526
# Epoch: 20 - Loss: 0.345821
# Epoch: 20 - Loss: 0.239211
# Epoch: 20 - valid Loss: 0.190446 - valid_acc : 0.932307
# Epoch: 21 - Loss: 0.141566
# Epoch: 21 - Loss: 0.396639
# Epoch: 21 - valid Loss: 0.203031 - valid_acc : 0.932307
# Epoch: 22 - Loss: 0.196274
# Epoch: 22 - Loss: 0.276969
# Epoch: 22 - valid Loss: 0.247595 - valid_acc : 0.908869
# Epoch: 23 - Loss: 0.351348
# Epoch: 23 - Loss: 0.345737
# Epoch: 23 - valid Loss: 0.191846 - valid_acc : 0.933869
# Epoch: 24 - Loss: 0.310510
# Epoch: 24 - Loss: 0.387762
# Epoch: 24 - valid Loss: 0.235089 - valid_acc : 0.918520
# Epoch: 25 - Loss: 0.622006
# Epoch: 25 - Loss: 0.254235
# Epoch: 25 - valid Loss: 0.222355 - valid_acc : 0.926838
# Epoch: 26 - Loss: 0.302848
# Epoch: 26 - Loss: 0.219347
# Epoch: 26 - valid Loss: 0.201165 - valid_acc : 0.927803
# Epoch: 27 - Loss: 0.166527
# Epoch: 27 - Loss: 0.371162
# Epoch: 27 - valid Loss: 0.161380 - valid_acc : 0.950965
# Epoch: 28 - Loss: 0.143813
# Epoch: 28 - Loss: 0.373551
# Epoch: 28 - valid Loss: 0.128678 - valid_acc : 0.955744
# Epoch: 29 - Loss: 0.449115
# Epoch: 29 - Loss: 0.296742
# Epoch: 29 - valid Loss: 0.144331 - valid_acc : 0.953401

# %%
test_transforms = A.Compose([
    A.Normalize(),
    ToTensor()
])

test_dataset = CustomDataset(test,'test/test','test',test_transforms)
test_loader = DataLoader(test_dataset, batch_size=64, shuffle=False, num_workers=0)

# %%
len(best_models)
# Out:
# 39

# %%
preds = []
for idx,model in enumerate(best_models[:1]): 
    print(idx+1, '번째 모델 예측 진행중')
    model = model
    model.eval()
    y_pred = []
    with torch.no_grad():
        for i, d in enumerate(test_loader):
            inputs = d.to('cuda')
            outputs = model(inputs).detach().cpu().numpy()
            y_pred.extend(outputs.argmax(axis=1).astype(int))
            
    preds.append(y_pred)
# Out:
# 1 번째 모델 예측 진행중

# %%
from collections import Counter
np_pred = np.array(preds).T

pred = []
for i in range(5000):
    cnt = Counter(np_pred[i])
    pred.append(cnt.most_common()[0][0])
#pred

# %%
submission = pd.read_csv('sample_submission.csv')
submission['label'] = pred

# %%
submission.to_csv('sub_211124.csv',index = False)

# %%
submission['label'].value_counts()
# Out:
# 7    649
# 6    639
# 1    546
# 4    529
# 8    517
# 9    489
# 0    467
# 2    459
# 3    356
# 5    349
# Name: label, dtype: int64
