# %%
import warnings
warnings.filterwarnings(action='ignore')

import os
import pandas as pd
import numpy as np

from PIL import Image
import matplotlib.pyplot as plt
# %matplotlib inline

from sklearn.model_selection import train_test_split
import IPython.display as ipd
import time

# %%
import torch
import torchvision
from torch import Tensor, nn, optim
from torch.utils.data import Dataset, DataLoader

import torch.nn.functional as F
import torch.nn as nn
import torchvision.transforms as transforms
import torchvision.models as models
from adamp import AdamP
from torchsummary import summary

import albumentations as A
from albumentations.pytorch import ToTensor
from efficientnet_pytorch import EfficientNet

# %% [markdown]
# ## 시드 고정

# %%
import random
def seed_everything(seed: int = 42):
    random.seed(seed)
    np.random.seed(seed)
    os.environ["PYTHONHASHSEED"] = str(seed)
    torch.manual_seed(seed)
    torch.cuda.manual_seed(seed)  
    torch.backends.cudnn.deterministic = True  
    torch.backends.cudnn.benchmark = True  
seed_everything()

# %% [markdown]
# ## 데이터 불러오기

# %%
train = pd.read_csv('./train/train_data.csv')
test = pd.read_csv('./test/test/test_data.csv')

# %%
train.columns = ['file_name','label']

# %%
train.head()
# Out:
#        file_name  label
# 0  train0001.png      8
# 1  train0002.png      8
# 2  train0003.png      8
# 3  train0004.png      8
# 4  train0005.png      8

# %%
test.head()
# Out:
#      file_name
# 0  idx0001.png
# 1  idx0002.png
# 2  idx0003.png
# 3  idx0004.png
# 4  idx0005.png

# %%
def get_transform(mode='train'):
    # Data Augmentation
    # 마가리따님의 '파이토치 데이터 증강법 (점수:0.835)' 참고 : https://dacon.io/competitions/official/235838/codeshare/3734?page=1&dtype=recent
    
    t = list()
    t.append(transforms.ToTensor())
    
    if mode == 'train':
        t.append(transforms.RandomAffine(degrees=10, translate=(0.1,0.1)))

    t.append(transforms.Normalize(mean=(.5),std=(.5)))
    
    return transforms.Compose(t)

# %%
class CustomDataset(torch.utils.data.Dataset): 
    def __init__(self,df,path,option,augmentation=None):
        self.df = df
        self.option = option
        self.augmentation = augmentation
        
        self.path = path

    def __len__(self):
        return len(self.df)
    
    def __getitem__(self, idx): 
        file_path  = self.df.iloc[idx,0]
        image=  Image.open(os.path.join(self.path,file_path)).convert('RGB')
        #image = image.resize((100,100))
        image = np.array(image)
        
        #image = transforms.ToTensor()(image=image)['image']
        
        
        if self.augmentation is not None:
            image = self.augmentation(image=image)['image']
        
        
        if self.option =='train':
            label = self.df.iloc[idx,1]
            label = torch.tensor(label, dtype=torch.int64)
            return image, label
        
        return image

# %%
class CNN(torch.nn.Module):

    def __init__(self):
        super(CNN, self).__init__()
        # 첫번째층
        # ImgIn shape=(batch_size, 28, 28, 2)
        #    Conv     -> (batch_size, 28, 28, 16)
        self.layer1 = torch.nn.Sequential(
            torch.nn.Conv2d(3, 16, kernel_size=3, stride=1, padding='same'),
            torch.nn.ReLU(),
            torch.nn.BatchNorm2d(16),
            torch.nn.Dropout(p=0.3))
        
        # 두번째층
        # ImgIn shape=(batch_size, 28, 28, 16)
        #    Conv      ->(batch_size, 28, 28, 32)
        #    Pool      ->(batch_size, 9, 9, 32)
        self.layer2 = torch.nn.Sequential(
            torch.nn.Conv2d(16, 32, kernel_size=3, stride=1, padding='same'),
            torch.nn.ReLU(),
            torch.nn.BatchNorm2d(32),
            torch.nn.Conv2d(32, 32, kernel_size=5, stride=1, padding='same'),
            torch.nn.ReLU(),
            torch.nn.BatchNorm2d(32),
            torch.nn.Conv2d(32, 32, kernel_size=5, stride=1, padding='same'),
            torch.nn.ReLU(),
            torch.nn.BatchNorm2d(32),
            torch.nn.Conv2d(32, 32, kernel_size=5, stride=1, padding='same'),
            torch.nn.ReLU(),
            torch.nn.BatchNorm2d(32),
            torch.nn.MaxPool2d(kernel_size=3, stride=3),
            torch.nn.Dropout(p=0.3))
        
        # 세번째층
        # ImgIn shape=(batch_size, 9, 9, 32)
        #    Conv      ->(batch_size, 9, 9, 64)
        #    Pool      ->(batch_size, 3, 3, 64)        
        self.layer3 = torch.nn.Sequential(
            torch.nn.Conv2d(32, 64, kernel_size=3, stride=1, padding='same'),
            torch.nn.ReLU(),
            torch.nn.BatchNorm2d(64),
            torch.nn.Conv2d(64, 64, kernel_size=3, stride=1, padding='same'),
            torch.nn.ReLU(),
            torch.nn.BatchNorm2d(64),
            torch.nn.MaxPool2d(kernel_size=3, stride=3),
            torch.nn.Dropout(p=0.3))
        
        # 전결합층 7x7x64 inputs -> 10 outputs
        self.fc = torch.nn.Linear(3*3*64, 10, bias=True)

        torch.nn.init.xavier_uniform_(self.fc.weight) # fc 가중치 초기화

    def forward(self, x):
        out = self.layer1(x)
        out = self.layer2(out)
        out = self.layer3(out)
        out = out.view(out.size(0), -1)   # Flatten
        out = self.fc(out)
        return out

# %%
class MnistModel(nn.Module):
    def __init__(self,):
        super().__init__()
        #self.conv2d = nn.Conv2d(3, 3, 3, stride=1)
        self.model = torchvision.models.resnet18(pretrained = False)
        #self.model = EfficientNet.from_name('efficientnet-b1')
        self.dropout = nn.Dropout(0.5)
        
        self.classifier = nn.Linear(1000, 10)

    def forward(self, images):
        #outputs = self.conv2d(images)
        outputs = self.model(images)
        outputs = self.dropout(outputs)
        outputs = self.classifier(outputs)
        return outputs

# %%
class EarlyStopping:
    # 참고: https://github.com/Bjarten/early-stopping-pytorch/blob/master/pytorchtools.py
    
    """주어진 patience 이후로 validation loss가 개선되지 않으면 학습을 조기 중지"""
    def __init__(self, patience=7, verbose=False, delta=0, k_num=0):
        """
        Args:
            patience (int): validation loss가 개선된 후 기다리는 기간
                            Default: 7
            verbose (bool): True일 경우 각 validation loss의 개선 사항 메세지 출력
                            Default: False
            delta (float): 개선되었다고 인정되는 monitered quantity의 최소 변화
                            Default: 0
            path (str): checkpoint저장 경로
                            Default: 'checkpoint.pt'
        """
        self.patience = patience
        self.verbose = verbose
        self.counter = 0
        self.best_score = None
        self.early_stop = False
        self.val_loss_min = np.Inf
        self.delta = delta
        
        self.k_num = k_num

    def __call__(self, val_loss, model):

        score = -val_loss

        if self.best_score is None:
            self.best_score = score
            #self.save_checkpoint(val_loss, model)
        elif score < self.best_score + self.delta:
            self.counter += 1
#             print(f'EarlyStopping counter: {self.counter} out of {self.patience}')
            if self.counter >= self.patience:
                self.early_stop = True
        else:
            self.best_score = score
            #self.save_checkpoint(val_loss, model)
            self.counter = 0

    def save_checkpoint(self, val_loss, model):
        '''validation loss가 감소하면 모델을 저장한다.'''
        if self.verbose:
            print(f'Validation loss decreased ({self.val_loss_min:.6f} --> {val_loss:.6f}).  Saving model ...')
        torch.save(model.state_dict(), self.path + f'/best_{k_num}.pt')
        self.val_loss_min = val_loss

# %%
from sklearn.model_selection import StratifiedKFold

skf = StratifiedKFold(n_splits = 5)
folds=[]
for trn_idx,val_idx in skf.split(train['file_name'],train['label']):
    folds.append((trn_idx,val_idx))

# %%
num_epochs = 50
best_models = [] # 폴드별로 가장 validation acc가 높은 모델 저장
k_num = 0

for i,fold in enumerate(range(5)):
    print('===============',i+1,'fold start===============')
    
    model = CNN().to('cuda')
    k_num += 1
    early_stopping = EarlyStopping(patience = 300, verbose = True, k_num = k_num)
    
    #optimizer = AdamP(model.parameters(), lr=1e-3, )
    optimizer = optim.SGD(model.parameters(), lr=1e-3, )
    criterion = nn.CrossEntropyLoss()
    lr_scheduler = torch.optim.lr_scheduler.StepLR(optimizer,
                                                step_size = 5,
                                                gamma = 0.9)
        
    
    train_idx = folds[fold][0]
    valid_idx = folds[fold][1]
    
    train_data = train.loc[trn_idx]
    val_data = train.loc[valid_idx]
    
    train_transforms = A.Compose([
    A.Normalize(),
    ToTensor()
    ])

    test_transforms = A.Compose([
        A.Normalize(),
        ToTensor()
        ])

    train_dataset = CustomDataset(train_data,'train/','train',train_transforms)
    train_loader = DataLoader(train_dataset, batch_size=64, shuffle=True, num_workers=0)

    valid_dataset = CustomDataset(val_data,'train/','train',test_transforms)
    valid_loader = DataLoader(valid_dataset, batch_size=64, shuffle=False, num_workers=0)
    
    
    valid_acc_max = 0.85
    valid_loss_min = 0.4
    for epoch in range(num_epochs):

        for i, (images, targets) in enumerate(train_loader):
            model.train()
            images, targets = images.to('cuda'), targets.to('cuda')

            optimizer.zero_grad()
            outputs = model(images)

            loss = criterion(outputs, targets)
            loss.backward()
            optimizer.step()  

            if (i+1) % 20 == 0:
                print(f'Epoch: {epoch} - Loss: {loss:.6f}')


        val_loss = []
        val_acc = []
        for i, (images, targets) in enumerate(valid_loader):
            model.eval()
            images, targets = images.to('cuda'), targets.to('cuda')

            with torch.no_grad():
                outputs = model(images)
                valid_loss = criterion(outputs,targets).cpu().detach().numpy()

                preds = torch.argmax(outputs,axis = 1)
                preds = preds.cpu().detach().numpy()

                targets = targets.cpu().detach().numpy()
                batch_acc = (preds==targets).mean()



                val_loss.append(valid_loss)
                val_acc.append(batch_acc)

        val_loss = np.mean(val_loss)
        val_acc = np.mean(val_acc)

        print(f'Epoch: {epoch} - valid Loss: {val_loss:.6f} - valid_acc : {val_acc:.6f}')
        early_stopping(float(val_loss), model)
        if early_stopping.early_stop:
            print("Early stopping!!")
            break       
        
        '''
         if valid_acc_max < val_acc:
            valid_acc_max = val_acc
            best_models.append(model)
            print('model save, model val acc : ',val_acc)
            print('best_models size : ',len(best_models))
            '''


        if valid_loss_min > val_loss:
            valid_loss_min = val_loss
            best_models.append(model)
            
    # Learning rate 조절
    lr_scheduler.step()
# Out:
# =============== 1 fold start===============
# Epoch: 0 - Loss: 3.242912
# Epoch: 0 - Loss: 2.826890
# Epoch: 0 - Loss: 1.860245
# Epoch: 0 - valid Loss: 0.905390 - valid_acc : 0.681641
# Epoch: 1 - Loss: 1.255856
# Epoch: 1 - Loss: 1.245807
# Epoch: 1 - Loss: 1.273116
# Epoch: 1 - valid Loss: 0.369037 - valid_acc : 0.884766
# Epoch: 2 - Loss: 0.787956
# Epoch: 2 - Loss: 0.715223
# Epoch: 2 - Loss: 0.538051
# Epoch: 2 - valid Loss: 0.250748 - valid_acc : 0.925781
# Epoch: 3 - Loss: 0.956386
# Epoch: 3 - Loss: 0.580319
# Epoch: 3 - Loss: 0.521698
# Epoch: 3 - valid Loss: 0.207277 - valid_acc : 0.942383
# Epoch: 4 - Loss: 0.511788
# Epoch: 4 - Loss: 0.581196
# Epoch: 4 - Loss: 0.409695
# Epoch: 4 - valid Loss: 0.161027 - valid_acc : 0.952539
# Epoch: 5 - Loss: 0.356975
# Epoch: 5 - Loss: 0.411231
# Epoch: 5 - Loss: 0.369376
# Epoch: 5 - valid Loss: 0.134437 - valid_acc : 0.961914
# Epoch: 6 - Loss: 0.398980
# Epoch: 6 - Loss: 0.382625
# Epoch: 6 - Loss: 0.302937
# Epoch: 6 - valid Loss: 0.120492 - valid_acc : 0.961914
# Epoch: 7 - Loss: 0.478519
# Epoch: 7 - Loss: 0.157193
# Epoch: 7 - Loss: 0.382253
# Epoch: 7 - valid Loss: 0.110824 - valid_acc : 0.967773
# Epoch: 8 - Loss: 0.234139
# Epoch: 8 - Loss: 0.290337
# Epoch: 8 - Loss: 0.405494
# Epoch: 8 - valid Loss: 0.093203 - valid_acc : 0.975586
# Epoch: 9 - Loss: 0.104028
# Epoch: 9 - Loss: 0.199659
# Epoch: 9 - Loss: 0.385471
# Epoch: 9 - valid Loss: 0.082720 - valid_acc : 0.975586
# Epoch: 10 - Loss: 0.393447
# Epoch: 10 - Loss: 0.242055
# Epoch: 10 - Loss: 0.352210
# Epoch: 10 - valid Loss: 0.076739 - valid_acc : 0.974609
# Epoch: 11 - Loss: 0.305100
# Epoch: 11 - Loss: 0.381963
# Epoch: 11 - Loss: 0.234269
# Epoch: 11 - valid Loss: 0.071291 - valid_acc : 0.980469
# Epoch: 12 - Loss: 0.267894
# Epoch: 12 - Loss: 0.200459
# Epoch: 12 - Loss: 0.096756
# Epoch: 12 - valid Loss: 0.063692 - valid_acc : 0.982422
# Epoch: 13 - Loss: 0.171993
# Epoch: 13 - Loss: 0.169658
# Epoch: 13 - Loss: 0.196353
# Epoch: 13 - valid Loss: 0.059497 - valid_acc : 0.983398
# Epoch: 14 - Loss: 0.102536
# Epoch: 14 - Loss: 0.224689
# Epoch: 14 - Loss: 0.150507
# Epoch: 14 - valid Loss: 0.057905 - valid_acc : 0.984375
# Epoch: 15 - Loss: 0.106353
# Epoch: 15 - Loss: 0.069643
# Epoch: 15 - Loss: 0.395532
# Epoch: 15 - valid Loss: 0.055061 - valid_acc : 0.984375
# Epoch: 16 - Loss: 0.295848
# Epoch: 16 - Loss: 0.221910
# Epoch: 16 - Loss: 0.134876
# Epoch: 16 - valid Loss: 0.049775 - valid_acc : 0.986328
# Epoch: 17 - Loss: 0.072854
# Epoch: 17 - Loss: 0.333556
# Epoch: 17 - Loss: 0.148905
# Epoch: 17 - valid Loss: 0.049876 - valid_acc : 0.988281
# Epoch: 18 - Loss: 0.249050
# Epoch: 18 - Loss: 0.090707
# Epoch: 18 - Loss: 0.176446
# Epoch: 18 - valid Loss: 0.045458 - valid_acc : 0.989258
# Epoch: 19 - Loss: 0.129712
# Epoch: 19 - Loss: 0.110999
# Epoch: 19 - Loss: 0.160866
# Epoch: 19 - valid Loss: 0.042928 - valid_acc : 0.989258
# Epoch: 20 - Loss: 0.267168
# Epoch: 20 - Loss: 0.160407
# Epoch: 20 - Loss: 0.218804
# Epoch: 20 - valid Loss: 0.042551 - valid_acc : 0.988281
# Epoch: 21 - Loss: 0.228729
# Epoch: 21 - Loss: 0.133330
# Epoch: 21 - Loss: 0.110955
# Epoch: 21 - valid Loss: 0.039368 - valid_acc : 0.990234
# Epoch: 22 - Loss: 0.051906
# Epoch: 22 - Loss: 0.110199
# Epoch: 22 - Loss: 0.081647
# Epoch: 22 - valid Loss: 0.038956 - valid_acc : 0.987305
# Epoch: 23 - Loss: 0.084059
# Epoch: 23 - Loss: 0.064307
# Epoch: 23 - Loss: 0.132620
# Epoch: 23 - valid Loss: 0.037495 - valid_acc : 0.990234
# Epoch: 24 - Loss: 0.315725
# Epoch: 24 - Loss: 0.074490
# Epoch: 24 - Loss: 0.150933
# Epoch: 24 - valid Loss: 0.035019 - valid_acc : 0.989258
# Epoch: 25 - Loss: 0.039627
# Epoch: 25 - Loss: 0.151862
# Epoch: 25 - Loss: 0.138550
# Epoch: 25 - valid Loss: 0.033324 - valid_acc : 0.989258
# Epoch: 26 - Loss: 0.078289
# Epoch: 26 - Loss: 0.072213
# Epoch: 26 - Loss: 0.070329
# Epoch: 26 - valid Loss: 0.029002 - valid_acc : 0.994141
# Epoch: 27 - Loss: 0.159168
# Epoch: 27 - Loss: 0.076511
# Epoch: 27 - Loss: 0.055037
# Epoch: 27 - valid Loss: 0.031160 - valid_acc : 0.993164
# Epoch: 28 - Loss: 0.193487
# Epoch: 28 - Loss: 0.160406
# Epoch: 28 - Loss: 0.038107
# Epoch: 28 - valid Loss: 0.028064 - valid_acc : 0.992188
# Epoch: 29 - Loss: 0.116315
# Epoch: 29 - Loss: 0.133150
# Epoch: 29 - Loss: 0.089634
# Epoch: 29 - valid Loss: 0.028919 - valid_acc : 0.992188
# Epoch: 30 - Loss: 0.139673
# Epoch: 30 - Loss: 0.042567
# Epoch: 30 - Loss: 0.032380
# Epoch: 30 - valid Loss: 0.027594 - valid_acc : 0.992188
# Epoch: 31 - Loss: 0.134689
# Epoch: 31 - Loss: 0.047242
# Epoch: 31 - Loss: 0.162006
# Epoch: 31 - valid Loss: 0.029181 - valid_acc : 0.992188
# Epoch: 32 - Loss: 0.128450
# Epoch: 32 - Loss: 0.074932
# Epoch: 32 - Loss: 0.168651
# Epoch: 32 - valid Loss: 0.025421 - valid_acc : 0.993164
# Epoch: 33 - Loss: 0.044414
# Epoch: 33 - Loss: 0.184736
# Epoch: 33 - Loss: 0.029599
# Epoch: 33 - valid Loss: 0.023237 - valid_acc : 0.992188
# Epoch: 34 - Loss: 0.061747
# Epoch: 34 - Loss: 0.180242
# Epoch: 34 - Loss: 0.206460
# Epoch: 34 - valid Loss: 0.024752 - valid_acc : 0.992188
# Epoch: 35 - Loss: 0.083385
# Epoch: 35 - Loss: 0.159533
# Epoch: 35 - Loss: 0.063506
# Epoch: 35 - valid Loss: 0.023242 - valid_acc : 0.993164
# Epoch: 36 - Loss: 0.161290
# Epoch: 36 - Loss: 0.112960
# Epoch: 36 - Loss: 0.110015
# Epoch: 36 - valid Loss: 0.025797 - valid_acc : 0.992188
# Epoch: 37 - Loss: 0.098511
# Epoch: 37 - Loss: 0.062219
# Epoch: 37 - Loss: 0.091722
# Epoch: 37 - valid Loss: 0.023000 - valid_acc : 0.993164
# Epoch: 38 - Loss: 0.127685
# Epoch: 38 - Loss: 0.130668
# Epoch: 38 - Loss: 0.048575
# Epoch: 38 - valid Loss: 0.022177 - valid_acc : 0.994141
# Epoch: 39 - Loss: 0.093520
# Epoch: 39 - Loss: 0.063536
# Epoch: 39 - Loss: 0.019356
# Epoch: 39 - valid Loss: 0.022632 - valid_acc : 0.993164
# Epoch: 40 - Loss: 0.055183
# Epoch: 40 - Loss: 0.036433
# Epoch: 40 - Loss: 0.124088
# Epoch: 40 - valid Loss: 0.018782 - valid_acc : 0.995117
# Epoch: 41 - Loss: 0.074994
# Epoch: 41 - Loss: 0.082074
# Epoch: 41 - Loss: 0.064274
# Epoch: 41 - valid Loss: 0.021418 - valid_acc : 0.993164
# Epoch: 42 - Loss: 0.045445
# Epoch: 42 - Loss: 0.095089
# Epoch: 42 - Loss: 0.017239
# Epoch: 42 - valid Loss: 0.020215 - valid_acc : 0.994141
# Epoch: 43 - Loss: 0.064396
# Epoch: 43 - Loss: 0.059978
# Epoch: 43 - Loss: 0.142404
# Epoch: 43 - valid Loss: 0.017047 - valid_acc : 0.995117
# Epoch: 44 - Loss: 0.028481
# Epoch: 44 - Loss: 0.028833
# Epoch: 44 - Loss: 0.039883
# Epoch: 44 - valid Loss: 0.017317 - valid_acc : 0.995117
# Epoch: 45 - Loss: 0.055069
# Epoch: 45 - Loss: 0.007997
# Epoch: 45 - Loss: 0.068623
# Epoch: 45 - valid Loss: 0.020693 - valid_acc : 0.992188
# Epoch: 46 - Loss: 0.038589
# Epoch: 46 - Loss: 0.032846
# Epoch: 46 - Loss: 0.041569
# Epoch: 46 - valid Loss: 0.021174 - valid_acc : 0.993164
# Epoch: 47 - Loss: 0.083203
# Epoch: 47 - Loss: 0.020930
# Epoch: 47 - Loss: 0.078963
# Epoch: 47 - valid Loss: 0.018189 - valid_acc : 0.995117
# Epoch: 48 - Loss: 0.131414
# Epoch: 48 - Loss: 0.033826
# Epoch: 48 - Loss: 0.047237
# Epoch: 48 - valid Loss: 0.019886 - valid_acc : 0.994141
# Epoch: 49 - Loss: 0.019984
# Epoch: 49 - Loss: 0.112600
# Epoch: 49 - Loss: 0.075789
# Epoch: 49 - valid Loss: 0.015545 - valid_acc : 0.996094
# =============== 2 fold start===============
# Epoch: 0 - Loss: 3.712889
# Epoch: 0 - Loss: 3.259831
# Epoch: 0 - Loss: 1.578838
# Epoch: 0 - valid Loss: 0.681184 - valid_acc : 0.789062
# Epoch: 1 - Loss: 1.212048
# Epoch: 1 - Loss: 1.304649
# Epoch: 1 - Loss: 1.064861
# Epoch: 1 - valid Loss: 0.313848 - valid_acc : 0.904687
# Epoch: 2 - Loss: 0.643007
# Epoch: 2 - Loss: 0.547967
# Epoch: 2 - Loss: 0.746376
# Epoch: 2 - valid Loss: 0.235498 - valid_acc : 0.925195
# Epoch: 3 - Loss: 0.492254
# Epoch: 3 - Loss: 0.435990
# Epoch: 3 - Loss: 0.691225
# Epoch: 3 - valid Loss: 0.171745 - valid_acc : 0.953125
# Epoch: 4 - Loss: 0.486618
# Epoch: 4 - Loss: 0.248874
# Epoch: 4 - Loss: 0.345309
# Epoch: 4 - valid Loss: 0.142781 - valid_acc : 0.959961
# Epoch: 5 - Loss: 0.417158
# Epoch: 5 - Loss: 0.467753
# Epoch: 5 - Loss: 0.310773
# Epoch: 5 - valid Loss: 0.122464 - valid_acc : 0.967773
# Epoch: 6 - Loss: 0.168667
# Epoch: 6 - Loss: 0.276207
# Epoch: 6 - Loss: 0.199170
# Epoch: 6 - valid Loss: 0.109924 - valid_acc : 0.966797
# Epoch: 7 - Loss: 0.161969
# Epoch: 7 - Loss: 0.159266
# Epoch: 7 - Loss: 0.240277
# Epoch: 7 - valid Loss: 0.094388 - valid_acc : 0.972656
# Epoch: 8 - Loss: 0.432106
# Epoch: 8 - Loss: 0.128419
# Epoch: 8 - Loss: 0.262244
# Epoch: 8 - valid Loss: 0.086686 - valid_acc : 0.975586
# Epoch: 9 - Loss: 0.249354
# Epoch: 9 - Loss: 0.189867
# Epoch: 9 - Loss: 0.307061
# Epoch: 9 - valid Loss: 0.080425 - valid_acc : 0.977539
# Epoch: 10 - Loss: 0.183750
# Epoch: 10 - Loss: 0.091238
# Epoch: 10 - Loss: 0.173014
# Epoch: 10 - valid Loss: 0.073333 - valid_acc : 0.981445
# Epoch: 11 - Loss: 0.276216
# Epoch: 11 - Loss: 0.630406
# Epoch: 11 - Loss: 0.143098
# Epoch: 11 - valid Loss: 0.068632 - valid_acc : 0.985352
# Epoch: 12 - Loss: 0.158337
# Epoch: 12 - Loss: 0.243938
# Epoch: 12 - Loss: 0.139553
# Epoch: 12 - valid Loss: 0.065103 - valid_acc : 0.984375
# Epoch: 13 - Loss: 0.438954
# Epoch: 13 - Loss: 0.133845
# Epoch: 13 - Loss: 0.100377
# Epoch: 13 - valid Loss: 0.058969 - valid_acc : 0.986328
# Epoch: 14 - Loss: 0.107536
# Epoch: 14 - Loss: 0.131477
# Epoch: 14 - Loss: 0.194030
# Epoch: 14 - valid Loss: 0.056901 - valid_acc : 0.985352
# Epoch: 15 - Loss: 0.255509
# Epoch: 15 - Loss: 0.210349
# Epoch: 15 - Loss: 0.137284
# Epoch: 15 - valid Loss: 0.055973 - valid_acc : 0.987305
# Epoch: 16 - Loss: 0.062346
# Epoch: 16 - Loss: 0.275123
# Epoch: 16 - Loss: 0.117860
# Epoch: 16 - valid Loss: 0.052871 - valid_acc : 0.984375
# Epoch: 17 - Loss: 0.067825
# Epoch: 17 - Loss: 0.048336
# Epoch: 17 - Loss: 0.158510
# Epoch: 17 - valid Loss: 0.048355 - valid_acc : 0.987305
# Epoch: 18 - Loss: 0.171919
# Epoch: 18 - Loss: 0.074098
# Epoch: 18 - Loss: 0.085907
# Epoch: 18 - valid Loss: 0.046957 - valid_acc : 0.986328
# Epoch: 19 - Loss: 0.064683
# Epoch: 19 - Loss: 0.213999
# Epoch: 19 - Loss: 0.077035
# Epoch: 19 - valid Loss: 0.047091 - valid_acc : 0.987305
# Epoch: 20 - Loss: 0.373539
# Epoch: 20 - Loss: 0.174358
# Epoch: 20 - Loss: 0.103662
# Epoch: 20 - valid Loss: 0.042958 - valid_acc : 0.987305
# Epoch: 21 - Loss: 0.169572
# Epoch: 21 - Loss: 0.131584
# Epoch: 21 - Loss: 0.340266
# Epoch: 21 - valid Loss: 0.040403 - valid_acc : 0.987305
# Epoch: 22 - Loss: 0.022177
# Epoch: 22 - Loss: 0.088209
# Epoch: 22 - Loss: 0.055723
# Epoch: 22 - valid Loss: 0.039846 - valid_acc : 0.987305
# Epoch: 23 - Loss: 0.131097
# Epoch: 23 - Loss: 0.114141
# Epoch: 23 - Loss: 0.029074
# Epoch: 23 - valid Loss: 0.037661 - valid_acc : 0.989258
# Epoch: 24 - Loss: 0.087410
# Epoch: 24 - Loss: 0.029832
# Epoch: 24 - Loss: 0.066378
# Epoch: 24 - valid Loss: 0.034387 - valid_acc : 0.989258
# Epoch: 25 - Loss: 0.071075
# Epoch: 25 - Loss: 0.138814
# Epoch: 25 - Loss: 0.061120
# Epoch: 25 - valid Loss: 0.033522 - valid_acc : 0.989258
# Epoch: 26 - Loss: 0.105413
# Epoch: 26 - Loss: 0.150779
# Epoch: 26 - Loss: 0.048711
# Epoch: 26 - valid Loss: 0.031073 - valid_acc : 0.990234
# Epoch: 27 - Loss: 0.073142
# Epoch: 27 - Loss: 0.135183
# Epoch: 27 - Loss: 0.060530
# Epoch: 27 - valid Loss: 0.030556 - valid_acc : 0.989258
# Epoch: 28 - Loss: 0.059233
# Epoch: 28 - Loss: 0.346109
# Epoch: 28 - Loss: 0.150577
# Epoch: 28 - valid Loss: 0.031330 - valid_acc : 0.991211
# Epoch: 29 - Loss: 0.062509
# Epoch: 29 - Loss: 0.061457
# Epoch: 29 - Loss: 0.121226
# Epoch: 29 - valid Loss: 0.029219 - valid_acc : 0.992188
# Epoch: 30 - Loss: 0.076190
# Epoch: 30 - Loss: 0.089343
# Epoch: 30 - Loss: 0.102145
# Epoch: 30 - valid Loss: 0.026781 - valid_acc : 0.991211
# Epoch: 31 - Loss: 0.082972
# Epoch: 31 - Loss: 0.064231
# Epoch: 31 - Loss: 0.059673
# Epoch: 31 - valid Loss: 0.024339 - valid_acc : 0.992188
# Epoch: 32 - Loss: 0.054284
# Epoch: 32 - Loss: 0.046099
# Epoch: 32 - Loss: 0.081798
# Epoch: 32 - valid Loss: 0.024571 - valid_acc : 0.992188
# Epoch: 33 - Loss: 0.228632
# Epoch: 33 - Loss: 0.074127
# Epoch: 33 - Loss: 0.077670
# Epoch: 33 - valid Loss: 0.023384 - valid_acc : 0.993164
# Epoch: 34 - Loss: 0.051719
# Epoch: 34 - Loss: 0.059059
# Epoch: 34 - Loss: 0.042168
# Epoch: 34 - valid Loss: 0.023291 - valid_acc : 0.992188
# Epoch: 35 - Loss: 0.214449
# Epoch: 35 - Loss: 0.105362
# Epoch: 35 - Loss: 0.193085
# Epoch: 35 - valid Loss: 0.021717 - valid_acc : 0.992188
# Epoch: 36 - Loss: 0.178623
# Epoch: 36 - Loss: 0.032116
# Epoch: 36 - Loss: 0.102036
# Epoch: 36 - valid Loss: 0.020251 - valid_acc : 0.994141
# Epoch: 37 - Loss: 0.060789
# Epoch: 37 - Loss: 0.040834
# Epoch: 37 - Loss: 0.022518
# Epoch: 37 - valid Loss: 0.018946 - valid_acc : 0.993164
# Epoch: 38 - Loss: 0.099594
# Epoch: 38 - Loss: 0.028136
# Epoch: 38 - Loss: 0.127448
# Epoch: 38 - valid Loss: 0.019277 - valid_acc : 0.993164
# Epoch: 39 - Loss: 0.066447
# Epoch: 39 - Loss: 0.067380
# Epoch: 39 - Loss: 0.014134
# Epoch: 39 - valid Loss: 0.018683 - valid_acc : 0.993164
# Epoch: 40 - Loss: 0.067007
# Epoch: 40 - Loss: 0.086995
# Epoch: 40 - Loss: 0.063376
# Epoch: 40 - valid Loss: 0.018212 - valid_acc : 0.993164
# Epoch: 41 - Loss: 0.036760
# Epoch: 41 - Loss: 0.048339
# Epoch: 41 - Loss: 0.070389
# Epoch: 41 - valid Loss: 0.016504 - valid_acc : 0.994141
# Epoch: 42 - Loss: 0.146543
# Epoch: 42 - Loss: 0.055985
# Epoch: 42 - Loss: 0.057037
# Epoch: 42 - valid Loss: 0.017261 - valid_acc : 0.994141
# Epoch: 43 - Loss: 0.045312
# Epoch: 43 - Loss: 0.166657
# Epoch: 43 - Loss: 0.024374
# Epoch: 43 - valid Loss: 0.016848 - valid_acc : 0.994141
# Epoch: 44 - Loss: 0.038455
# Epoch: 44 - Loss: 0.033214
# Epoch: 44 - Loss: 0.115316
# Epoch: 44 - valid Loss: 0.016108 - valid_acc : 0.994141
# Epoch: 45 - Loss: 0.027289
# Epoch: 45 - Loss: 0.013294
# Epoch: 45 - Loss: 0.047023
# Epoch: 45 - valid Loss: 0.015177 - valid_acc : 0.997070
# Epoch: 46 - Loss: 0.119148
# Epoch: 46 - Loss: 0.017933
# Epoch: 46 - Loss: 0.116858
# Epoch: 46 - valid Loss: 0.014130 - valid_acc : 0.997070
# Epoch: 47 - Loss: 0.007236
# Epoch: 47 - Loss: 0.118932
# Epoch: 47 - Loss: 0.131271
# Epoch: 47 - valid Loss: 0.013574 - valid_acc : 0.997070
# Epoch: 48 - Loss: 0.100698
# Epoch: 48 - Loss: 0.027772
# Epoch: 48 - Loss: 0.014265
# Epoch: 48 - valid Loss: 0.012875 - valid_acc : 0.997070
# Epoch: 49 - Loss: 0.027162
# Epoch: 49 - Loss: 0.071715
# Epoch: 49 - Loss: 0.063909
# Epoch: 49 - valid Loss: 0.012635 - valid_acc : 0.998047
# =============== 3 fold start===============
# Epoch: 0 - Loss: 3.531624
# Epoch: 0 - Loss: 2.618457
# Epoch: 0 - Loss: 2.459907
# Epoch: 0 - valid Loss: 0.885669 - valid_acc : 0.705664
# Epoch: 1 - Loss: 1.789564
# Epoch: 1 - Loss: 1.321129
# Epoch: 1 - Loss: 1.143809
# Epoch: 1 - valid Loss: 0.399790 - valid_acc : 0.878516
# Epoch: 2 - Loss: 1.066462
# Epoch: 2 - Loss: 0.756448
# Epoch: 2 - Loss: 0.669923
# Epoch: 2 - valid Loss: 0.239592 - valid_acc : 0.937305
# Epoch: 3 - Loss: 0.569967
# Epoch: 3 - Loss: 0.528414
# Epoch: 3 - Loss: 0.443546
# Epoch: 3 - valid Loss: 0.191630 - valid_acc : 0.942187
# Epoch: 4 - Loss: 0.438148
# Epoch: 4 - Loss: 0.477668
# Epoch: 4 - Loss: 0.386116
# Epoch: 4 - valid Loss: 0.154360 - valid_acc : 0.954492
# Epoch: 5 - Loss: 0.628591
# Epoch: 5 - Loss: 0.238792
# Epoch: 5 - Loss: 0.334519
# Epoch: 5 - valid Loss: 0.126467 - valid_acc : 0.962305
# Epoch: 6 - Loss: 0.332275
# Epoch: 6 - Loss: 0.447969
# Epoch: 6 - Loss: 0.419048
# Epoch: 6 - valid Loss: 0.115011 - valid_acc : 0.963281
# Epoch: 7 - Loss: 0.275436
# Epoch: 7 - Loss: 0.237606
# Epoch: 7 - Loss: 0.356860
# Epoch: 7 - valid Loss: 0.093984 - valid_acc : 0.968164
# Epoch: 8 - Loss: 0.389985
# Epoch: 8 - Loss: 0.218987
# Epoch: 8 - Loss: 0.173946
# Epoch: 8 - valid Loss: 0.089815 - valid_acc : 0.974023
# Epoch: 9 - Loss: 0.502396
# Epoch: 9 - Loss: 0.101962
# Epoch: 9 - Loss: 0.277277
# Epoch: 9 - valid Loss: 0.077752 - valid_acc : 0.979883
# Epoch: 10 - Loss: 0.231171
# Epoch: 10 - Loss: 0.346771
# Epoch: 10 - Loss: 0.167982
# Epoch: 10 - valid Loss: 0.078135 - valid_acc : 0.975977
# Epoch: 11 - Loss: 0.126679
# Epoch: 11 - Loss: 0.091576
# Epoch: 11 - Loss: 0.267000
# Epoch: 11 - valid Loss: 0.068443 - valid_acc : 0.978906
# Epoch: 12 - Loss: 0.093565
# Epoch: 12 - Loss: 0.213591
# Epoch: 12 - Loss: 0.167048
# Epoch: 12 - valid Loss: 0.061065 - valid_acc : 0.978906
# Epoch: 13 - Loss: 0.198044
# Epoch: 13 - Loss: 0.142901
# Epoch: 13 - Loss: 0.202252
# Epoch: 13 - valid Loss: 0.060746 - valid_acc : 0.981836
# Epoch: 14 - Loss: 0.167284
# Epoch: 14 - Loss: 0.153283
# Epoch: 14 - Loss: 0.235559
# Epoch: 14 - valid Loss: 0.051540 - valid_acc : 0.984766
# Epoch: 15 - Loss: 0.207962
# Epoch: 15 - Loss: 0.134618
# Epoch: 15 - Loss: 0.083746
# Epoch: 15 - valid Loss: 0.050084 - valid_acc : 0.987695
# Epoch: 16 - Loss: 0.105201
# Epoch: 16 - Loss: 0.090589
# Epoch: 16 - Loss: 0.184728
# Epoch: 16 - valid Loss: 0.050022 - valid_acc : 0.986719
# Epoch: 17 - Loss: 0.100282
# Epoch: 17 - Loss: 0.153240
# Epoch: 17 - Loss: 0.142106
# Epoch: 17 - valid Loss: 0.049197 - valid_acc : 0.985742
# Epoch: 18 - Loss: 0.076982
# Epoch: 18 - Loss: 0.124066
# Epoch: 18 - Loss: 0.198788
# Epoch: 18 - valid Loss: 0.041740 - valid_acc : 0.988672
# Epoch: 19 - Loss: 0.239997
# Epoch: 19 - Loss: 0.150522
# Epoch: 19 - Loss: 0.099245
# Epoch: 19 - valid Loss: 0.039756 - valid_acc : 0.986719
# Epoch: 20 - Loss: 0.159031
# Epoch: 20 - Loss: 0.098453
# Epoch: 20 - Loss: 0.120673
# Epoch: 20 - valid Loss: 0.039540 - valid_acc : 0.987695
# Epoch: 21 - Loss: 0.170918
# Epoch: 21 - Loss: 0.227507
# Epoch: 21 - Loss: 0.195334
# Epoch: 21 - valid Loss: 0.033689 - valid_acc : 0.993164
# Epoch: 22 - Loss: 0.075132
# Epoch: 22 - Loss: 0.027023
# Epoch: 22 - Loss: 0.062434
# Epoch: 22 - valid Loss: 0.034011 - valid_acc : 0.991211
# Epoch: 23 - Loss: 0.148211
# Epoch: 23 - Loss: 0.121891
# Epoch: 23 - Loss: 0.226644
# Epoch: 23 - valid Loss: 0.032707 - valid_acc : 0.992188
# Epoch: 24 - Loss: 0.066715
# Epoch: 24 - Loss: 0.063284
# Epoch: 24 - Loss: 0.192317
# Epoch: 24 - valid Loss: 0.032839 - valid_acc : 0.991211
# Epoch: 25 - Loss: 0.126188
# Epoch: 25 - Loss: 0.191520
# Epoch: 25 - Loss: 0.036938
# Epoch: 25 - valid Loss: 0.030878 - valid_acc : 0.991211
# Epoch: 26 - Loss: 0.087856
# Epoch: 26 - Loss: 0.116089
# Epoch: 26 - Loss: 0.030384
# Epoch: 26 - valid Loss: 0.035829 - valid_acc : 0.990234
# Epoch: 27 - Loss: 0.072889
# Epoch: 27 - Loss: 0.054576
# Epoch: 27 - Loss: 0.066434
# Epoch: 27 - valid Loss: 0.027185 - valid_acc : 0.991211
# Epoch: 28 - Loss: 0.236566
# Epoch: 28 - Loss: 0.091800
# Epoch: 28 - Loss: 0.066799
# Epoch: 28 - valid Loss: 0.024180 - valid_acc : 0.995117
# Epoch: 29 - Loss: 0.076855
# Epoch: 29 - Loss: 0.064522
# Epoch: 29 - Loss: 0.057782
# Epoch: 29 - valid Loss: 0.024974 - valid_acc : 0.994141
# Epoch: 30 - Loss: 0.073552
# Epoch: 30 - Loss: 0.067637
# Epoch: 30 - Loss: 0.081726
# Epoch: 30 - valid Loss: 0.023490 - valid_acc : 0.994141
# Epoch: 31 - Loss: 0.035817
# Epoch: 31 - Loss: 0.138704
# Epoch: 31 - Loss: 0.055022
# Epoch: 31 - valid Loss: 0.024104 - valid_acc : 0.995117
# Epoch: 32 - Loss: 0.016852
# Epoch: 32 - Loss: 0.119223
# Epoch: 32 - Loss: 0.059723
# Epoch: 32 - valid Loss: 0.022500 - valid_acc : 0.995117
# Epoch: 33 - Loss: 0.064812
# Epoch: 33 - Loss: 0.091803
# Epoch: 33 - Loss: 0.060425
# Epoch: 33 - valid Loss: 0.024215 - valid_acc : 0.994141
# Epoch: 34 - Loss: 0.044441
# Epoch: 34 - Loss: 0.135081
# Epoch: 34 - Loss: 0.038369
# Epoch: 34 - valid Loss: 0.021279 - valid_acc : 0.993164
# Epoch: 35 - Loss: 0.052386
# Epoch: 35 - Loss: 0.085067
# Epoch: 35 - Loss: 0.059071
# Epoch: 35 - valid Loss: 0.022087 - valid_acc : 0.995117
# Epoch: 36 - Loss: 0.098062
# Epoch: 36 - Loss: 0.097182
# Epoch: 36 - Loss: 0.051595
# Epoch: 36 - valid Loss: 0.019690 - valid_acc : 0.996094
# Epoch: 37 - Loss: 0.035488
# Epoch: 37 - Loss: 0.039404
# Epoch: 37 - Loss: 0.077470
# Epoch: 37 - valid Loss: 0.019354 - valid_acc : 0.995117
# Epoch: 38 - Loss: 0.106268
# Epoch: 38 - Loss: 0.058740
# Epoch: 38 - Loss: 0.154566
# Epoch: 38 - valid Loss: 0.019264 - valid_acc : 0.995117
# Epoch: 39 - Loss: 0.091836
# Epoch: 39 - Loss: 0.118271
# Epoch: 39 - Loss: 0.110448
# Epoch: 39 - valid Loss: 0.019056 - valid_acc : 0.995117
# Epoch: 40 - Loss: 0.073013
# Epoch: 40 - Loss: 0.042570
# Epoch: 40 - Loss: 0.021742
# Epoch: 40 - valid Loss: 0.018984 - valid_acc : 0.996094
# Epoch: 41 - Loss: 0.099212
# Epoch: 41 - Loss: 0.061695
# Epoch: 41 - Loss: 0.080225
# Epoch: 41 - valid Loss: 0.017186 - valid_acc : 0.995117
# Epoch: 42 - Loss: 0.086119
# Epoch: 42 - Loss: 0.018382
# Epoch: 42 - Loss: 0.019093
# Epoch: 42 - valid Loss: 0.017325 - valid_acc : 0.995117
# Epoch: 43 - Loss: 0.157862
# Epoch: 43 - Loss: 0.147550
# Epoch: 43 - Loss: 0.195645
# Epoch: 43 - valid Loss: 0.017269 - valid_acc : 0.996094
# Epoch: 44 - Loss: 0.023641
# Epoch: 44 - Loss: 0.038883
# Epoch: 44 - Loss: 0.053285
# Epoch: 44 - valid Loss: 0.014993 - valid_acc : 0.996094
# Epoch: 45 - Loss: 0.040464
# Epoch: 45 - Loss: 0.140524
# Epoch: 45 - Loss: 0.052131
# Epoch: 45 - valid Loss: 0.016515 - valid_acc : 0.995117
# Epoch: 46 - Loss: 0.056167
# Epoch: 46 - Loss: 0.083882
# Epoch: 46 - Loss: 0.135001
# Epoch: 46 - valid Loss: 0.014961 - valid_acc : 0.995117
# Epoch: 47 - Loss: 0.048668
# Epoch: 47 - Loss: 0.021214
# Epoch: 47 - Loss: 0.172963
# Epoch: 47 - valid Loss: 0.016473 - valid_acc : 0.995117
# Epoch: 48 - Loss: 0.190498
# Epoch: 48 - Loss: 0.039201
# Epoch: 48 - Loss: 0.067502
# Epoch: 48 - valid Loss: 0.015342 - valid_acc : 0.996094
# Epoch: 49 - Loss: 0.070687
# Epoch: 49 - Loss: 0.061281
# Epoch: 49 - Loss: 0.036322
# Epoch: 49 - valid Loss: 0.013352 - valid_acc : 0.996094
# =============== 4 fold start===============
# Epoch: 0 - Loss: 3.390873
# Epoch: 0 - Loss: 2.329427
# Epoch: 0 - Loss: 2.268312
# Epoch: 0 - valid Loss: 0.808153 - valid_acc : 0.728906
# Epoch: 1 - Loss: 1.251416
# Epoch: 1 - Loss: 0.989973
# Epoch: 1 - Loss: 0.849798
# Epoch: 1 - valid Loss: 0.332690 - valid_acc : 0.889453
# Epoch: 2 - Loss: 0.679450
# Epoch: 2 - Loss: 0.947950
# Epoch: 2 - Loss: 0.609047
# Epoch: 2 - valid Loss: 0.264520 - valid_acc : 0.916797
# Epoch: 3 - Loss: 0.379173
# Epoch: 3 - Loss: 0.622174
# Epoch: 3 - Loss: 0.445403
# Epoch: 3 - valid Loss: 0.216141 - valid_acc : 0.930469
# Epoch: 4 - Loss: 0.349089
# Epoch: 4 - Loss: 0.561176
# Epoch: 4 - Loss: 0.392602
# Epoch: 4 - valid Loss: 0.167704 - valid_acc : 0.947070
# Epoch: 5 - Loss: 0.278088
# Epoch: 5 - Loss: 0.185146
# Epoch: 5 - Loss: 0.313412
# Epoch: 5 - valid Loss: 0.145504 - valid_acc : 0.951953
# Epoch: 6 - Loss: 0.410048
# Epoch: 6 - Loss: 0.445850
# Epoch: 6 - Loss: 0.154782
# Epoch: 6 - valid Loss: 0.126424 - valid_acc : 0.957422
# Epoch: 7 - Loss: 0.157237
# Epoch: 7 - Loss: 0.302496
# Epoch: 7 - Loss: 0.123901
# Epoch: 7 - valid Loss: 0.112989 - valid_acc : 0.964648
# Epoch: 8 - Loss: 0.194729
# Epoch: 8 - Loss: 0.321680
# Epoch: 8 - Loss: 0.269455
# Epoch: 8 - valid Loss: 0.104352 - valid_acc : 0.968555
# Epoch: 9 - Loss: 0.329058
# Epoch: 9 - Loss: 0.297453
# Epoch: 9 - Loss: 0.201247
# Epoch: 9 - valid Loss: 0.090814 - valid_acc : 0.970508
# Epoch: 10 - Loss: 0.150130
# Epoch: 10 - Loss: 0.188175
# Epoch: 10 - Loss: 0.224666
# Epoch: 10 - valid Loss: 0.091077 - valid_acc : 0.967578
# Epoch: 11 - Loss: 0.286229
# Epoch: 11 - Loss: 0.332910
# Epoch: 11 - Loss: 0.235905
# Epoch: 11 - valid Loss: 0.074480 - valid_acc : 0.975391
# Epoch: 12 - Loss: 0.145887
# Epoch: 12 - Loss: 0.215360
# Epoch: 12 - Loss: 0.149913
# Epoch: 12 - valid Loss: 0.077236 - valid_acc : 0.977930
# Epoch: 13 - Loss: 0.321848
# Epoch: 13 - Loss: 0.107423
# Epoch: 13 - Loss: 0.150266
# Epoch: 13 - valid Loss: 0.076509 - valid_acc : 0.974023
# Epoch: 14 - Loss: 0.157553
# Epoch: 14 - Loss: 0.208806
# Epoch: 14 - Loss: 0.109563
# Epoch: 14 - valid Loss: 0.070140 - valid_acc : 0.977930
# Epoch: 15 - Loss: 0.231510
# Epoch: 15 - Loss: 0.168609
# Epoch: 15 - Loss: 0.152603
# Epoch: 15 - valid Loss: 0.074552 - valid_acc : 0.974023
# Epoch: 16 - Loss: 0.163909
# Epoch: 16 - Loss: 0.087227
# Epoch: 16 - Loss: 0.146417
# Epoch: 16 - valid Loss: 0.067445 - valid_acc : 0.975977
# Epoch: 17 - Loss: 0.155628
# Epoch: 17 - Loss: 0.157018
# Epoch: 17 - Loss: 0.094515
# Epoch: 17 - valid Loss: 0.058242 - valid_acc : 0.981836
# Epoch: 18 - Loss: 0.048411
# Epoch: 18 - Loss: 0.122046
# Epoch: 18 - Loss: 0.172074
# Epoch: 18 - valid Loss: 0.051189 - valid_acc : 0.985742
# Epoch: 19 - Loss: 0.021784
# Epoch: 19 - Loss: 0.252769
# Epoch: 19 - Loss: 0.116174
# Epoch: 19 - valid Loss: 0.054138 - valid_acc : 0.979883
# Epoch: 20 - Loss: 0.025689
# Epoch: 20 - Loss: 0.127305
# Epoch: 20 - Loss: 0.198594
# Epoch: 20 - valid Loss: 0.044396 - valid_acc : 0.987695
# Epoch: 21 - Loss: 0.116179
# Epoch: 21 - Loss: 0.170349
# Epoch: 21 - Loss: 0.154837
# Epoch: 21 - valid Loss: 0.044164 - valid_acc : 0.987695
# Epoch: 22 - Loss: 0.076324
# Epoch: 22 - Loss: 0.208586
# Epoch: 22 - Loss: 0.116045
# Epoch: 22 - valid Loss: 0.041861 - valid_acc : 0.989648
# Epoch: 23 - Loss: 0.114095
# Epoch: 23 - Loss: 0.151896
# Epoch: 23 - Loss: 0.233906
# Epoch: 23 - valid Loss: 0.042342 - valid_acc : 0.988672
# Epoch: 24 - Loss: 0.095920
# Epoch: 24 - Loss: 0.148978
# Epoch: 24 - Loss: 0.048580
# Epoch: 24 - valid Loss: 0.042029 - valid_acc : 0.988281
# Epoch: 25 - Loss: 0.075550
# Epoch: 25 - Loss: 0.087875
# Epoch: 25 - Loss: 0.061776
# Epoch: 25 - valid Loss: 0.033714 - valid_acc : 0.991211
# Epoch: 26 - Loss: 0.057436
# Epoch: 26 - Loss: 0.029773
# Epoch: 26 - Loss: 0.161404
# Epoch: 26 - valid Loss: 0.033141 - valid_acc : 0.993164
# Epoch: 27 - Loss: 0.145104
# Epoch: 27 - Loss: 0.120488
# Epoch: 27 - Loss: 0.185894
# Epoch: 27 - valid Loss: 0.036906 - valid_acc : 0.992188
# Epoch: 28 - Loss: 0.018700
# Epoch: 28 - Loss: 0.026559
# Epoch: 28 - Loss: 0.016107
# Epoch: 28 - valid Loss: 0.032772 - valid_acc : 0.991211
# Epoch: 29 - Loss: 0.119387
# Epoch: 29 - Loss: 0.067421
# Epoch: 29 - Loss: 0.054502
# Epoch: 29 - valid Loss: 0.034500 - valid_acc : 0.993164
# Epoch: 30 - Loss: 0.188430
# Epoch: 30 - Loss: 0.107408
# Epoch: 30 - Loss: 0.153064
# Epoch: 30 - valid Loss: 0.038501 - valid_acc : 0.992188
# Epoch: 31 - Loss: 0.100405
# Epoch: 31 - Loss: 0.101434
# Epoch: 31 - Loss: 0.119939
# Epoch: 31 - valid Loss: 0.029508 - valid_acc : 0.993164
# Epoch: 32 - Loss: 0.034324
# Epoch: 32 - Loss: 0.184385
# Epoch: 32 - Loss: 0.135206
# Epoch: 32 - valid Loss: 0.028744 - valid_acc : 0.995117
# Epoch: 33 - Loss: 0.041667
# Epoch: 33 - Loss: 0.036305
# Epoch: 33 - Loss: 0.076153
# Epoch: 33 - valid Loss: 0.026005 - valid_acc : 0.995117
# Epoch: 34 - Loss: 0.036181
# Epoch: 34 - Loss: 0.127833
# Epoch: 34 - Loss: 0.048332
# Epoch: 34 - valid Loss: 0.027943 - valid_acc : 0.993164
# Epoch: 35 - Loss: 0.036310
# Epoch: 35 - Loss: 0.108331
# Epoch: 35 - Loss: 0.017028
# Epoch: 35 - valid Loss: 0.025785 - valid_acc : 0.995117
# Epoch: 36 - Loss: 0.058736
# Epoch: 36 - Loss: 0.066337
# Epoch: 36 - Loss: 0.077963
# Epoch: 36 - valid Loss: 0.025155 - valid_acc : 0.995117
# Epoch: 37 - Loss: 0.098521
# Epoch: 37 - Loss: 0.114493
# Epoch: 37 - Loss: 0.078691
# Epoch: 37 - valid Loss: 0.025199 - valid_acc : 0.995117
# Epoch: 38 - Loss: 0.113550
# Epoch: 38 - Loss: 0.209326
# Epoch: 38 - Loss: 0.034435
# Epoch: 38 - valid Loss: 0.026389 - valid_acc : 0.994141
# Epoch: 39 - Loss: 0.040696
# Epoch: 39 - Loss: 0.086664
# Epoch: 39 - Loss: 0.102341
# Epoch: 39 - valid Loss: 0.024938 - valid_acc : 0.995117
# Epoch: 40 - Loss: 0.107650
# Epoch: 40 - Loss: 0.074161
# Epoch: 40 - Loss: 0.035117
# Epoch: 40 - valid Loss: 0.025412 - valid_acc : 0.994141
# Epoch: 41 - Loss: 0.112186
# Epoch: 41 - Loss: 0.068294
# Epoch: 41 - Loss: 0.062005
# Epoch: 41 - valid Loss: 0.018817 - valid_acc : 0.995117
# Epoch: 42 - Loss: 0.095277
# Epoch: 42 - Loss: 0.086176
# Epoch: 42 - Loss: 0.113648
# Epoch: 42 - valid Loss: 0.017418 - valid_acc : 0.995117
# Epoch: 43 - Loss: 0.112252
# Epoch: 43 - Loss: 0.071970
# Epoch: 43 - Loss: 0.060719
# Epoch: 43 - valid Loss: 0.021932 - valid_acc : 0.995117
# Epoch: 44 - Loss: 0.036670
# Epoch: 44 - Loss: 0.042977
# Epoch: 44 - Loss: 0.047552
# Epoch: 44 - valid Loss: 0.020759 - valid_acc : 0.993164
# Epoch: 45 - Loss: 0.128536
# Epoch: 45 - Loss: 0.029944
# Epoch: 45 - Loss: 0.105441
# Epoch: 45 - valid Loss: 0.020626 - valid_acc : 0.995117
# Epoch: 46 - Loss: 0.042705
# Epoch: 46 - Loss: 0.124368
# Epoch: 46 - Loss: 0.090049
# Epoch: 46 - valid Loss: 0.018082 - valid_acc : 0.995117
# Epoch: 47 - Loss: 0.082671
# Epoch: 47 - Loss: 0.014273
# Epoch: 47 - Loss: 0.043115
# Epoch: 47 - valid Loss: 0.016520 - valid_acc : 0.996094
# Epoch: 48 - Loss: 0.105176
# Epoch: 48 - Loss: 0.052088
# Epoch: 48 - Loss: 0.060096
# Epoch: 48 - valid Loss: 0.015485 - valid_acc : 0.996094
# Epoch: 49 - Loss: 0.048708
# Epoch: 49 - Loss: 0.023150
# Epoch: 49 - Loss: 0.145616
# Epoch: 49 - valid Loss: 0.016286 - valid_acc : 0.995117
# =============== 5 fold start===============
# Epoch: 0 - Loss: 3.129778
# Epoch: 0 - Loss: 2.837155
# Epoch: 0 - Loss: 2.147285
# Epoch: 0 - valid Loss: 0.754776 - valid_acc : 0.751953
# Epoch: 1 - Loss: 1.369463
# Epoch: 1 - Loss: 1.203094
# Epoch: 1 - Loss: 0.843092
# Epoch: 1 - valid Loss: 0.306196 - valid_acc : 0.904687
# Epoch: 2 - Loss: 0.814694
# Epoch: 2 - Loss: 0.901026
# Epoch: 2 - Loss: 0.700219
# Epoch: 2 - valid Loss: 0.210344 - valid_acc : 0.930664
# Epoch: 3 - Loss: 0.540547
# Epoch: 3 - Loss: 0.609402
# Epoch: 3 - Loss: 0.539505
# Epoch: 3 - valid Loss: 0.168388 - valid_acc : 0.946289
# Epoch: 4 - Loss: 0.484567
# Epoch: 4 - Loss: 0.342436
# Epoch: 4 - Loss: 0.373160
# Epoch: 4 - valid Loss: 0.155916 - valid_acc : 0.945703
# Epoch: 5 - Loss: 0.183374
# Epoch: 5 - Loss: 0.198530
# Epoch: 5 - Loss: 0.256693
# Epoch: 5 - valid Loss: 0.132758 - valid_acc : 0.952539
# Epoch: 6 - Loss: 0.279807
# Epoch: 6 - Loss: 0.324169
# Epoch: 6 - Loss: 0.528025
# Epoch: 6 - valid Loss: 0.118307 - valid_acc : 0.959961
# Epoch: 7 - Loss: 0.398678
# Epoch: 7 - Loss: 0.217521
# Epoch: 7 - Loss: 0.144551
# Epoch: 7 - valid Loss: 0.110119 - valid_acc : 0.958008
# Epoch: 8 - Loss: 0.304723
# Epoch: 8 - Loss: 0.415498
# Epoch: 8 - Loss: 0.348401
# Epoch: 8 - valid Loss: 0.100444 - valid_acc : 0.963867
# Epoch: 9 - Loss: 0.203686
# Epoch: 9 - Loss: 0.261197
# Epoch: 9 - Loss: 0.440235
# Epoch: 9 - valid Loss: 0.092955 - valid_acc : 0.966797
# Epoch: 10 - Loss: 0.168593
# Epoch: 10 - Loss: 0.254132
# Epoch: 10 - Loss: 0.266151
# Epoch: 10 - valid Loss: 0.087590 - valid_acc : 0.966797
# Epoch: 11 - Loss: 0.322893
# Epoch: 11 - Loss: 0.142006
# Epoch: 11 - Loss: 0.161158
# Epoch: 11 - valid Loss: 0.082022 - valid_acc : 0.972656
# Epoch: 12 - Loss: 0.296317
# Epoch: 12 - Loss: 0.248313
# Epoch: 12 - Loss: 0.118609
# Epoch: 12 - valid Loss: 0.085253 - valid_acc : 0.965820
# Epoch: 13 - Loss: 0.126502
# Epoch: 13 - Loss: 0.226412
# Epoch: 13 - Loss: 0.241615
# Epoch: 13 - valid Loss: 0.071850 - valid_acc : 0.977539
# Epoch: 14 - Loss: 0.205083
# Epoch: 14 - Loss: 0.249149
# Epoch: 14 - Loss: 0.194659
# Epoch: 14 - valid Loss: 0.073471 - valid_acc : 0.972656
# Epoch: 15 - Loss: 0.356998
# Epoch: 15 - Loss: 0.165462
# Epoch: 15 - Loss: 0.120039
# Epoch: 15 - valid Loss: 0.068648 - valid_acc : 0.979492
# Epoch: 16 - Loss: 0.124856
# Epoch: 16 - Loss: 0.058520
# Epoch: 16 - Loss: 0.158195
# Epoch: 16 - valid Loss: 0.070317 - valid_acc : 0.977539
# Epoch: 17 - Loss: 0.081964
# Epoch: 17 - Loss: 0.126066
# Epoch: 17 - Loss: 0.032370
# Epoch: 17 - valid Loss: 0.063129 - valid_acc : 0.979492
# Epoch: 18 - Loss: 0.319587
# Epoch: 18 - Loss: 0.223901
# Epoch: 18 - Loss: 0.118384
# Epoch: 18 - valid Loss: 0.058544 - valid_acc : 0.980469
# Epoch: 19 - Loss: 0.184408
# Epoch: 19 - Loss: 0.060252
# Epoch: 19 - Loss: 0.139184
# Epoch: 19 - valid Loss: 0.059102 - valid_acc : 0.981445
# Epoch: 20 - Loss: 0.082684
# Epoch: 20 - Loss: 0.079356
# Epoch: 20 - Loss: 0.170230
# Epoch: 20 - valid Loss: 0.056782 - valid_acc : 0.982422
# Epoch: 21 - Loss: 0.256222
# Epoch: 21 - Loss: 0.121998
# Epoch: 21 - Loss: 0.031953
# Epoch: 21 - valid Loss: 0.056819 - valid_acc : 0.983398
# Epoch: 22 - Loss: 0.067957
# Epoch: 22 - Loss: 0.066715
# Epoch: 22 - Loss: 0.304412
# Epoch: 22 - valid Loss: 0.054703 - valid_acc : 0.980469
# Epoch: 23 - Loss: 0.104697
# Epoch: 23 - Loss: 0.124941
# Epoch: 23 - Loss: 0.101683
# Epoch: 23 - valid Loss: 0.054084 - valid_acc : 0.982422
# Epoch: 24 - Loss: 0.199192
# Epoch: 24 - Loss: 0.071014
# Epoch: 24 - Loss: 0.019328
# Epoch: 24 - valid Loss: 0.056184 - valid_acc : 0.982422
# Epoch: 25 - Loss: 0.145616
# Epoch: 25 - Loss: 0.097548
# Epoch: 25 - Loss: 0.047627
# Epoch: 25 - valid Loss: 0.053484 - valid_acc : 0.983398
# Epoch: 26 - Loss: 0.163553
# Epoch: 26 - Loss: 0.029285
# Epoch: 26 - Loss: 0.109584
# Epoch: 26 - valid Loss: 0.050005 - valid_acc : 0.984375
# Epoch: 27 - Loss: 0.061495
# Epoch: 27 - Loss: 0.033471
# Epoch: 27 - Loss: 0.131431
# Epoch: 27 - valid Loss: 0.049990 - valid_acc : 0.985352
# Epoch: 28 - Loss: 0.077655
# Epoch: 28 - Loss: 0.088292
# Epoch: 28 - Loss: 0.128579
# Epoch: 28 - valid Loss: 0.048798 - valid_acc : 0.985352
# Epoch: 29 - Loss: 0.066430
# Epoch: 29 - Loss: 0.104264
# Epoch: 29 - Loss: 0.109600
# Epoch: 29 - valid Loss: 0.046751 - valid_acc : 0.986328
# Epoch: 30 - Loss: 0.064207
# Epoch: 30 - Loss: 0.216945
# Epoch: 30 - Loss: 0.064429
# Epoch: 30 - valid Loss: 0.047102 - valid_acc : 0.984375
# Epoch: 31 - Loss: 0.102209
# Epoch: 31 - Loss: 0.060062
# Epoch: 31 - Loss: 0.061713
# Epoch: 31 - valid Loss: 0.042241 - valid_acc : 0.986328
# Epoch: 32 - Loss: 0.017646
# Epoch: 32 - Loss: 0.054253
# Epoch: 32 - Loss: 0.048567
# Epoch: 32 - valid Loss: 0.042146 - valid_acc : 0.987305
# Epoch: 33 - Loss: 0.065413
# Epoch: 33 - Loss: 0.136707
# Epoch: 33 - Loss: 0.291222
# Epoch: 33 - valid Loss: 0.044784 - valid_acc : 0.985352
# Epoch: 34 - Loss: 0.216301
# Epoch: 34 - Loss: 0.045874
# Epoch: 34 - Loss: 0.090543
# Epoch: 34 - valid Loss: 0.040687 - valid_acc : 0.986328
# Epoch: 35 - Loss: 0.107427
# Epoch: 35 - Loss: 0.087111
# Epoch: 35 - Loss: 0.061306
# Epoch: 35 - valid Loss: 0.041813 - valid_acc : 0.986328
# Epoch: 36 - Loss: 0.065424
# Epoch: 36 - Loss: 0.055120
# Epoch: 36 - Loss: 0.055903
# Epoch: 36 - valid Loss: 0.039067 - valid_acc : 0.989258
# Epoch: 37 - Loss: 0.127042
# Epoch: 37 - Loss: 0.097296
# Epoch: 37 - Loss: 0.058252
# Epoch: 37 - valid Loss: 0.039094 - valid_acc : 0.988281
# Epoch: 38 - Loss: 0.103606
# Epoch: 38 - Loss: 0.080479
# Epoch: 38 - Loss: 0.087848
# Epoch: 38 - valid Loss: 0.037242 - valid_acc : 0.987305
# Epoch: 39 - Loss: 0.018286
# Epoch: 39 - Loss: 0.076596
# Epoch: 39 - Loss: 0.024666
# Epoch: 39 - valid Loss: 0.036704 - valid_acc : 0.987305
# Epoch: 40 - Loss: 0.047693
# Epoch: 40 - Loss: 0.040593
# Epoch: 40 - Loss: 0.282930
# Epoch: 40 - valid Loss: 0.037194 - valid_acc : 0.988281
# Epoch: 41 - Loss: 0.145085
# Epoch: 41 - Loss: 0.013979
# Epoch: 41 - Loss: 0.019084
# Epoch: 41 - valid Loss: 0.035403 - valid_acc : 0.990234
# Epoch: 42 - Loss: 0.015007
# Epoch: 42 - Loss: 0.101361
# Epoch: 42 - Loss: 0.108659
# Epoch: 42 - valid Loss: 0.036357 - valid_acc : 0.988281
# Epoch: 43 - Loss: 0.114718
# Epoch: 43 - Loss: 0.089764
# Epoch: 43 - Loss: 0.024823
# Epoch: 43 - valid Loss: 0.034655 - valid_acc : 0.989258
# Epoch: 44 - Loss: 0.046787
# Epoch: 44 - Loss: 0.087674
# Epoch: 44 - Loss: 0.050941
# Epoch: 44 - valid Loss: 0.035441 - valid_acc : 0.989258
# Epoch: 45 - Loss: 0.048919
# Epoch: 45 - Loss: 0.103269
# Epoch: 45 - Loss: 0.029687
# Epoch: 45 - valid Loss: 0.035139 - valid_acc : 0.989258
# Epoch: 46 - Loss: 0.085725
# Epoch: 46 - Loss: 0.065597
# Epoch: 46 - Loss: 0.075267
# Epoch: 46 - valid Loss: 0.034585 - valid_acc : 0.989258
# Epoch: 47 - Loss: 0.035628
# Epoch: 47 - Loss: 0.055258
# Epoch: 47 - Loss: 0.032076
# Epoch: 47 - valid Loss: 0.034145 - valid_acc : 0.989258
# Epoch: 48 - Loss: 0.109644
# Epoch: 48 - Loss: 0.175216
# Epoch: 48 - Loss: 0.197282
# Epoch: 48 - valid Loss: 0.033568 - valid_acc : 0.989258
# Epoch: 49 - Loss: 0.046079
# Epoch: 49 - Loss: 0.108747
# Epoch: 49 - Loss: 0.057475
# Epoch: 49 - valid Loss: 0.032924 - valid_acc : 0.989258

# %%
test_transforms = A.Compose([
    A.Normalize(),
    ToTensor()
])

test_dataset = CustomDataset(test,'test/test','test',test_transforms)
test_loader = DataLoader(test_dataset, batch_size=64, shuffle=False, num_workers=0)

# %%
len(best_models)
# Out:
# 178

# %%
preds = []
for idx,model in enumerate(best_models): 
    print(idx+1, '번째 모델 예측 진행중')
    model = model
    model.eval()
    y_pred = []
    with torch.no_grad():
        for i, d in enumerate(test_loader):
            inputs = d.to('cuda')
            outputs = model(inputs).detach().cpu().numpy()
            y_pred.extend(outputs.argmax(axis=1).astype(int))
            
    preds.append(y_pred)
# Out:
# 1 번째 모델 예측 진행중
# 2 번째 모델 예측 진행중
# 3 번째 모델 예측 진행중
# 4 번째 모델 예측 진행중
# 5 번째 모델 예측 진행중
# 6 번째 모델 예측 진행중
# 7 번째 모델 예측 진행중
# 8 번째 모델 예측 진행중
# 9 번째 모델 예측 진행중
# 10 번째 모델 예측 진행중
# 11 번째 모델 예측 진행중
# 12 번째 모델 예측 진행중
# 13 번째 모델 예측 진행중
# 14 번째 모델 예측 진행중
# 15 번째 모델 예측 진행중
# 16 번째 모델 예측 진행중
# 17 번째 모델 예측 진행중
# 18 번째 모델 예측 진행중
# 19 번째 모델 예측 진행중
# 20 번째 모델 예측 진행중
# 21 번째 모델 예측 진행중
# 22 번째 모델 예측 진행중
# 23 번째 모델 예측 진행중
# 24 번째 모델 예측 진행중
# 25 번째 모델 예측 진행중
# 26 번째 모델 예측 진행중
# 27 번째 모델 예측 진행중
# 28 번째 모델 예측 진행중
# 29 번째 모델 예측 진행중
# 30 번째 모델 예측 진행중
# 31 번째 모델 예측 진행중
# 32 번째 모델 예측 진행중
# 33 번째 모델 예측 진행중
# 34 번째 모델 예측 진행중
# 35 번째 모델 예측 진행중
# 36 번째 모델 예측 진행중
# 37 번째 모델 예측 진행중
# 38 번째 모델 예측 진행중
# 39 번째 모델 예측 진행중
# 40 번째 모델 예측 진행중
# 41 번째 모델 예측 진행중
# 42 번째 모델 예측 진행중
# 43 번째 모델 예측 진행중
# 44 번째 모델 예측 진행중
# 45 번째 모델 예측 진행중
# 46 번째 모델 예측 진행중
# 47 번째 모델 예측 진행중
# 48 번째 모델 예측 진행중
# 49 번째 모델 예측 진행중
# 50 번째 모델 예측 진행중
# 51 번째 모델 예측 진행중
# 52 번째 모델 예측 진행중
# 53 번째 모델 예측 진행중
# 54 번째 모델 예측 진행중
# 55 번째 모델 예측 진행중
# 56 번째 모델 예측 진행중
# 57 번째 모델 예측 진행중
# 58 번째 모델 예측 진행중
# 59 번째 모델 예측 진행중
# 60 번째 모델 예측 진행중
# 61 번째 모델 예측 진행중
# 62 번째 모델 예측 진행중
# 63 번째 모델 예측 진행중
# 64 번째 모델 예측 진행중
# 65 번째 모델 예측 진행중
# 66 번째 모델 예측 진행중
# 67 번째 모델 예측 진행중
# 68 번째 모델 예측 진행중
# 69 번째 모델 예측 진행중
# 70 번째 모델 예측 진행중
# 71 번째 모델 예측 진행중
# 72 번째 모델 예측 진행중
# 73 번째 모델 예측 진행중
# 74 번째 모델 예측 진행중
# 75 번째 모델 예측 진행중
# 76 번째 모델 예측 진행중
# 77 번째 모델 예측 진행중
# 78 번째 모델 예측 진행중
# 79 번째 모델 예측 진행중
# 80 번째 모델 예측 진행중
# 81 번째 모델 예측 진행중
# 82 번째 모델 예측 진행중
# 83 번째 모델 예측 진행중
# 84 번째 모델 예측 진행중
# 85 번째 모델 예측 진행중
# 86 번째 모델 예측 진행중
# 87 번째 모델 예측 진행중
# 88 번째 모델 예측 진행중
# 89 번째 모델 예측 진행중
# 90 번째 모델 예측 진행중
# 91 번째 모델 예측 진행중
# 92 번째 모델 예측 진행중
# 93 번째 모델 예측 진행중
# 94 번째 모델 예측 진행중
# 95 번째 모델 예측 진행중
# 96 번째 모델 예측 진행중
# 97 번째 모델 예측 진행중
# 98 번째 모델 예측 진행중
# 99 번째 모델 예측 진행중
# 100 번째 모델 예측 진행중
# 101 번째 모델 예측 진행중
# 102 번째 모델 예측 진행중
# 103 번째 모델 예측 진행중
# 104 번째 모델 예측 진행중
# 105 번째 모델 예측 진행중
# 106 번째 모델 예측 진행중
# 107 번째 모델 예측 진행중
# 108 번째 모델 예측 진행중
# 109 번째 모델 예측 진행중
# 110 번째 모델 예측 진행중
# 111 번째 모델 예측 진행중
# 112 번째 모델 예측 진행중
# 113 번째 모델 예측 진행중
# 114 번째 모델 예측 진행중
# 115 번째 모델 예측 진행중
# 116 번째 모델 예측 진행중
# 117 번째 모델 예측 진행중
# 118 번째 모델 예측 진행중
# 119 번째 모델 예측 진행중
# 120 번째 모델 예측 진행중
# 121 번째 모델 예측 진행중
# 122 번째 모델 예측 진행중
# 123 번째 모델 예측 진행중
# 124 번째 모델 예측 진행중
# 125 번째 모델 예측 진행중
# 126 번째 모델 예측 진행중
# 127 번째 모델 예측 진행중
# 128 번째 모델 예측 진행중
# 129 번째 모델 예측 진행중
# 130 번째 모델 예측 진행중
# 131 번째 모델 예측 진행중
# 132 번째 모델 예측 진행중
# 133 번째 모델 예측 진행중
# 134 번째 모델 예측 진행중
# 135 번째 모델 예측 진행중
# 136 번째 모델 예측 진행중
# 137 번째 모델 예측 진행중
# 138 번째 모델 예측 진행중
# 139 번째 모델 예측 진행중
# 140 번째 모델 예측 진행중
# 141 번째 모델 예측 진행중
# 142 번째 모델 예측 진행중
# 143 번째 모델 예측 진행중
# 144 번째 모델 예측 진행중
# 145 번째 모델 예측 진행중
# 146 번째 모델 예측 진행중
# 147 번째 모델 예측 진행중
# 148 번째 모델 예측 진행중
# 149 번째 모델 예측 진행중
# 150 번째 모델 예측 진행중
# 151 번째 모델 예측 진행중
# 152 번째 모델 예측 진행중
# 153 번째 모델 예측 진행중
# 154 번째 모델 예측 진행중
# 155 번째 모델 예측 진행중
# 156 번째 모델 예측 진행중
# 157 번째 모델 예측 진행중
# 158 번째 모델 예측 진행중
# 159 번째 모델 예측 진행중
# 160 번째 모델 예측 진행중
# 161 번째 모델 예측 진행중
# 162 번째 모델 예측 진행중
# 163 번째 모델 예측 진행중
# 164 번째 모델 예측 진행중
# 165 번째 모델 예측 진행중
# 166 번째 모델 예측 진행중
# 167 번째 모델 예측 진행중
# 168 번째 모델 예측 진행중
# 169 번째 모델 예측 진행중
# 170 번째 모델 예측 진행중
# 171 번째 모델 예측 진행중
# 172 번째 모델 예측 진행중
# 173 번째 모델 예측 진행중
# 174 번째 모델 예측 진행중
# 175 번째 모델 예측 진행중
# 176 번째 모델 예측 진행중
# 177 번째 모델 예측 진행중
# 178 번째 모델 예측 진행중

# %%
from collections import Counter
np_pred = np.array(preds).T

pred = []
for i in range(5000):
    cnt = Counter(np_pred[i])
    pred.append(cnt.most_common()[0][0])
#pred

# %%
submission = pd.read_csv('sample_submission.csv')
submission['label'] = pred

# %%
submission.to_csv('sub_211125.csv',index = False)

# %%
submission['label'].value_counts()
# Out:
# 1    663
# 6    587
# 0    555
# 9    531
# 7    526
# 2    467
# 5    467
# 3    461
# 4    449
# 8    294
# Name: label, dtype: int64
